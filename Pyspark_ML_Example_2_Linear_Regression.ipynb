# %%
from __future__ import print_function

from pyspark.ml.regression import LinearRegression

from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors

# %%
# Create a SparkSession (Note, the config section is only for Windows!)
spark = SparkSession.builder.appName("LinearRegression").getOrCreate()

# Load up our data and convert it to the format MLLib expects.
inputLines = spark.sparkContext.textFile("regression.txt")
data = inputLines.map(lambda x: x.split(",")).map(lambda x: (float(x[0]), Vectors.dense(float(x[1]))))

# %%
data.collect()
# Out:
# [(-1.74, DenseVector([1.66])),
#  (1.24, DenseVector([-1.18])),
#  (0.29, DenseVector([-0.4])),
#  (-0.13, DenseVector([0.09])),
#  (-0.39, DenseVector([0.38])),
#  (-1.79, DenseVector([1.73])),
#  (0.71, DenseVector([-0.77])),
#  (1.39, DenseVector([-1.48])),
#  (1.15, DenseVector([-1.43])),
#  (0.13, DenseVector([-0.07])),
#  (0.05, DenseVector([-0.07])),
#  (1.9, DenseVector([-1.8])),
#  (1.48, DenseVector([-1.42])),
#  (0.32, DenseVector([-0.3])),
#  (-1.11, DenseVector([1.0])),
#  (0.51, DenseVector([-0.62])),
#  (-1.58, DenseVector([1.45])),
#  (-0.46, DenseVector([0.44])),
#  (-0.49, DenseVector([0.37])),
#  (0.31, DenseVector([-0.3])),
#  (0.85, DenseVector([-0.77])),
#  (0.61, DenseVector([-0.69])),
#  (-0.66, DenseVector([0.65])),
#  (0.99, DenseVector([-0.94])),
#  (-0.73, DenseVector([0.62])),
#  (0.43, DenseVector([-0.42])),
#  (-0.5, DenseVector([0.35])),
#  (-1.77, DenseVector([1.66])),
#  (-0.65, DenseVector([0.88])),
#  (-2.29, DenseVector([2.35])),
#  (0.74, DenseVector([-0.66])),
#  (0.44, DenseVector([-0.44])),
#  (-0.41, DenseVector([0.51])),
#  (0.4, DenseVector([-0.36])),
#  (-2.17, DenseVector([2.19])),
#  (1.27, DenseVector([-1.11])),
#  (-0.94, DenseVector([1.0])),
#  (-0.59, DenseVector([0.66])),
#  (-0.04, DenseVector([0.01])),
#  (0.7, DenseVector([-0.89])),
#  (-0.85, DenseVector([0.8])),
#  (-0.14, DenseVector([0.02])),
#  (0.18, DenseVector([-0.18])),
#  (1.2, DenseVector([-1.15])),
#  (0.98, DenseVector([-0.91])),
#  (0.08, DenseVector([0.04])),
#  (-0.33, DenseVector([0.39])),
#  (-1.12, DenseVector([1.1])),
#  (0.08, DenseVector([-0.1])),
#  (-0.99, DenseVector([1.09])),
#  (-1.94, DenseVector([1.98])),
#  (0.18, DenseVector([-0.15])),
#  (0.44, DenseVector([-0.37])),
#  (-0.74, DenseVector([0.93])),
#  (2.39, DenseVector([-2.4])),
#  (-1.91, DenseVector([1.86])),
#  (-0.07, DenseVector([-0.09])),
#  (-2.0, DenseVector([2.02])),
#  (-0.36, DenseVector([0.56])),
#  (-0.52, DenseVector([0.69])),
#  (0.72, DenseVector([-0.81])),
#  (0.69, DenseVector([-0.73])),
#  (1.54, DenseVector([-1.49])),
#  (-2.26, DenseVector([2.25])),
#  (2.33, DenseVector([-2.15])),
#  (0.0, DenseVector([-0.07])),
#  (-1.3, DenseVector([1.45])),
#  (1.11, DenseVector([-1.16])),
#  (-0.23, DenseVector([0.29])),
#  (-0.14, DenseVector([0.13])),
#  (-0.04, DenseVector([0.13])),
#  (1.05, DenseVector([-0.8])),
#  (-1.22, DenseVector([1.2])),
#  (0.76, DenseVector([-0.77])),
#  (2.17, DenseVector([-2.02])),
#  (0.82, DenseVector([-0.96])),
#  (0.34, DenseVector([-0.36])),
#  (-1.61, DenseVector([1.72])),
#  (0.74, DenseVector([-0.64])),
#  (0.11, DenseVector([-0.09])),
#  (-1.4, DenseVector([1.32])),
#  (0.21, DenseVector([-0.23])),
#  (-1.96, DenseVector([1.98])),
#  (0.75, DenseVector([-0.92])),
#  (-0.59, DenseVector([0.63])),
#  (-1.39, DenseVector([1.32])),
#  (-1.26, DenseVector([1.17])),
#  (-0.53, DenseVector([0.5])),
#  (-1.1, DenseVector([0.92])),
#  (0.55, DenseVector([-0.68])),
#  (0.39, DenseVector([-0.42])),
#  (-1.48, DenseVector([1.38])),
#  (0.53, DenseVector([-0.56])),
#  (-0.96, DenseVector([1.06])),
#  (-1.3, DenseVector([1.14])),
#  (0.84, DenseVector([-0.84])),
#  (-1.16, DenseVector([1.25])),
#  (0.02, DenseVector([-0.05])),
#  (0.93, DenseVector([-0.79])),
#  (0.97, DenseVector([-0.98])),
#  (-0.65, DenseVector([0.54])),
#  (-2.07, DenseVector([2.04])),
#  (1.28, DenseVector([-1.27])),
#  (0.72, DenseVector([-0.81])),
#  (-1.65, DenseVector([1.63])),
#  (-0.07, DenseVector([-0.01])),
#  (-2.12, DenseVector([1.9])),
#  (-1.01, DenseVector([0.92])),
#  (1.06, DenseVector([-1.11])),
#  (-0.68, DenseVector([0.76])),
#  (1.32, DenseVector([-1.49])),
#  (-1.05, DenseVector([1.0])),
#  (-1.25, DenseVector([1.2])),
#  (-0.49, DenseVector([0.44])),
#  (0.11, DenseVector([-0.07])),
#  (-1.59, DenseVector([1.62])),
#  (0.14, DenseVector([-0.14])),
#  (-0.24, DenseVector([0.27])),
#  (-0.85, DenseVector([0.91])),
#  (1.19, DenseVector([-1.21])),
#  (1.51, DenseVector([-1.61])),
#  (-1.3, DenseVector([1.18])),
#  (0.17, DenseVector([-0.09])),
#  (0.03, DenseVector([-0.04])),
#  (-0.35, DenseVector([0.26])),
#  (0.21, DenseVector([-0.23])),
#  (-1.42, DenseVector([1.59])),
#  (1.28, DenseVector([-1.26])),
#  (-0.27, DenseVector([0.16])),
#  (0.26, DenseVector([-0.28])),
#  (1.55, DenseVector([-1.23])),
#  (-0.05, DenseVector([0.06])),
#  (0.37, DenseVector([-0.33])),
#  (-1.29, DenseVector([1.47])),
#  (-0.76, DenseVector([0.84])),
#  (0.1, DenseVector([0.02])),
#  (0.0, DenseVector([0.14])),
#  (-0.5, DenseVector([0.56])),
#  (-0.05, DenseVector([0.06])),
#  (-0.65, DenseVector([0.57])),
#  (0.41, DenseVector([-0.39])),
#  (0.09, DenseVector([-0.04])),
#  (-1.91, DenseVector([1.83])),
#  (0.81, DenseVector([-0.65])),
#  (-0.3, DenseVector([0.42])),
#  (0.18, DenseVector([-0.09])),
#  (0.61, DenseVector([-0.48])),
#  (0.76, DenseVector([-0.8])),
#  (1.18, DenseVector([-1.17])),
#  (-0.78, DenseVector([0.66])),
#  (-2.09, DenseVector([1.97])),
#  (-0.62, DenseVector([0.58])),
#  (-1.11, DenseVector([1.23])),
#  (2.56, DenseVector([-2.6])),
#  (0.35, DenseVector([-0.34])),
#  (1.47, DenseVector([-1.41])),
#  (0.14, DenseVector([-0.28])),
#  (0.85, DenseVector([-0.79])),
#  (0.22, DenseVector([-0.31])),
#  (-0.03, DenseVector([0.13])),
#  (-0.8, DenseVector([0.8])),
#  (0.84, DenseVector([-0.73])),
#  (-0.67, DenseVector([0.67])),
#  (-1.03, DenseVector([0.85])),
#  (0.95, DenseVector([-0.79])),
#  (0.51, DenseVector([-0.51])),
#  (-0.31, DenseVector([0.3])),
#  (0.3, DenseVector([-0.45])),
#  (-0.26, DenseVector([0.23])),
#  (1.63, DenseVector([-1.5])),
#  (-0.24, DenseVector([0.29])),
#  (-0.21, DenseVector([0.11])),
#  (0.64, DenseVector([-0.62])),
#  (1.49, DenseVector([-1.45])),
#  (0.26, DenseVector([-0.34])),
#  (-0.51, DenseVector([0.43])),
#  (0.81, DenseVector([-0.72])),
#  (-0.8, DenseVector([0.73])),
#  (-0.07, DenseVector([0.22])),
#  (1.22, DenseVector([-1.3])),
#  (-1.26, DenseVector([1.21])),
#  (-0.84, DenseVector([0.83])),
#  (1.91, DenseVector([-1.83])),
#  (0.1, DenseVector([-0.18])),
#  (-0.91, DenseVector([1.03])),
#  (0.74, DenseVector([-0.58])),
#  (0.12, DenseVector([-0.23])),
#  (0.39, DenseVector([-0.46])),
#  (-1.09, DenseVector([1.06])),
#  (-1.58, DenseVector([1.65])),
#  (-0.22, DenseVector([0.4])),
#  (-3.74, DenseVector([3.75])),
#  (0.16, DenseVector([-0.21])),
#  (0.4, DenseVector([-0.45])),
#  (1.72, DenseVector([-1.89])),
#  (-0.91, DenseVector([0.91])),
#  (-0.35, DenseVector([0.47])),
#  (0.9, DenseVector([-0.93])),
#  (0.93, DenseVector([-0.85])),
#  (0.15, DenseVector([-0.2])),
#  (0.01, DenseVector([-0.06])),
#  (0.15, DenseVector([-0.26])),
#  (0.73, DenseVector([-0.78])),
#  (-0.89, DenseVector([1.04])),
#  (-0.76, DenseVector([0.66])),
#  (1.07, DenseVector([-1.06])),
#  (0.29, DenseVector([-0.25])),
#  (0.17, DenseVector([-0.1])),
#  (-0.7, DenseVector([0.75])),
#  (0.29, DenseVector([-0.25])),
#  (1.5, DenseVector([-1.6])),
#  (0.98, DenseVector([-0.91])),
#  (-0.02, DenseVector([-0.11])),
#  (0.78, DenseVector([-0.79])),
#  (-1.09, DenseVector([1.18])),
#  (0.14, DenseVector([-0.11])),
#  (-0.53, DenseVector([0.31])),
#  (0.21, DenseVector([-0.25])),
#  (-0.45, DenseVector([0.32])),
#  (0.83, DenseVector([-0.81])),
#  (0.11, DenseVector([-0.16])),
#  (-0.24, DenseVector([0.26])),
#  (-0.36, DenseVector([0.41])),
#  (-1.2, DenseVector([1.2])),
#  (0.66, DenseVector([-0.66])),
#  (-0.01, DenseVector([0.21])),
#  (0.29, DenseVector([-0.21])),
#  (-0.95, DenseVector([1.08])),
#  (-0.28, DenseVector([0.42])),
#  (-0.16, DenseVector([0.22])),
#  (-1.88, DenseVector([1.89])),
#  (-1.36, DenseVector([1.41])),
#  (0.71, DenseVector([-0.85])),
#  (0.09, DenseVector([-0.16])),
#  (1.26, DenseVector([-1.35])),
#  (-0.6, DenseVector([0.61])),
#  (-0.95, DenseVector([0.81])),
#  (-0.68, DenseVector([0.88])),
#  (0.97, DenseVector([-0.85])),
#  (1.06, DenseVector([-1.05])),
#  (1.62, DenseVector([-1.8])),
#  (1.63, DenseVector([-1.62])),
#  (1.59, DenseVector([-1.77])),
#  (0.16, DenseVector([-0.06])),
#  (-0.01, DenseVector([-0.04])),
#  (0.54, DenseVector([-0.42])),
#  (-0.81, DenseVector([0.89])),
#  (2.25, DenseVector([-2.24])),
#  (-0.88, DenseVector([0.77])),
#  (0.64, DenseVector([-0.7])),
#  (0.33, DenseVector([-0.25])),
#  (-0.65, DenseVector([0.64])),
#  (-0.75, DenseVector([0.72])),
#  (-1.17, DenseVector([1.24])),
#  (-0.3, DenseVector([0.31])),
#  (1.52, DenseVector([-1.51])),
#  (0.07, DenseVector([0.09])),
#  (1.66, DenseVector([-1.67])),
#  (0.04, DenseVector([0.01])),
#  (-0.33, DenseVector([0.3])),
#  (0.46, DenseVector([-0.43])),
#  (0.59, DenseVector([-0.69])),
#  (1.18, DenseVector([-1.29])),
#  (0.97, DenseVector([-0.89])),
#  (1.05, DenseVector([-1.15])),
#  (1.64, DenseVector([-1.41])),
#  (0.43, DenseVector([-0.47])),
#  (0.58, DenseVector([-0.66])),
#  (-2.58, DenseVector([2.57])),
#  (0.15, DenseVector([-0.35])),
#  (0.23, DenseVector([-0.31])),
#  (0.21, DenseVector([-0.18])),
#  (-0.39, DenseVector([0.27])),
#  (0.53, DenseVector([-0.47])),
#  (-0.1, DenseVector([0.07])),
#  (-1.53, DenseVector([1.68])),
#  (0.3, DenseVector([-0.36])),
#  (-0.04, DenseVector([-0.13])),
#  (-1.24, DenseVector([1.09])),
#  (1.51, DenseVector([-1.57])),
#  (0.95, DenseVector([-1.01])),
#  (0.4, DenseVector([-0.39])),
#  (0.23, DenseVector([-0.24])),
#  (0.25, DenseVector([-0.18])),
#  (1.27, DenseVector([-1.17])),
#  (1.11, DenseVector([-1.2])),
#  (0.79, DenseVector([-0.72])),
#  (1.14, DenseVector([-1.21])),
#  (0.79, DenseVector([-0.68])),
#  (-0.82, DenseVector([0.7])),
#  (0.66, DenseVector([-0.71])),
#  (-0.08, DenseVector([0.14])),
#  (1.54, DenseVector([-1.52])),
#  (-0.71, DenseVector([0.55])),
#  (-0.42, DenseVector([0.45])),
#  (0.08, DenseVector([-0.06])),
#  (1.42, DenseVector([-1.31])),
#  (-0.05, DenseVector([-0.02])),
#  (1.83, DenseVector([-1.7])),
#  (0.24, DenseVector([-0.15])),
#  (0.65, DenseVector([-0.45])),
#  (0.2, DenseVector([-0.26])),
#  (-0.97, DenseVector([0.96])),
#  (0.9, DenseVector([-0.87])),
#  (0.29, DenseVector([-0.16])),
#  (1.32, DenseVector([-1.53])),
#  (-0.11, DenseVector([0.11])),
#  (1.03, DenseVector([-0.9])),
#  (-0.51, DenseVector([0.69])),
#  (1.14, DenseVector([-1.09])),
#  (1.64, DenseVector([-1.5])),
#  (-0.53, DenseVector([0.62])),
#  (2.48, DenseVector([-2.53])),
#  (-1.04, DenseVector([1.17])),
#  (1.1, DenseVector([-0.99])),
#  (-1.6, DenseVector([1.63])),
#  (-1.07, DenseVector([1.03])),
#  (0.49, DenseVector([-0.44])),
#  (-0.43, DenseVector([0.39])),
#  (0.46, DenseVector([-0.44])),
#  (-0.65, DenseVector([0.65])),
#  (-0.09, DenseVector([0.17])),
#  (0.87, DenseVector([-0.88])),
#  (0.34, DenseVector([-0.4])),
#  (0.97, DenseVector([-0.9])),
#  (0.25, DenseVector([-0.21])),
#  (1.96, DenseVector([-1.95])),
#  (0.7, DenseVector([-0.53])),
#  (-1.46, DenseVector([1.41])),
#  (-1.57, DenseVector([1.56])),
#  (-0.98, DenseVector([1.03])),
#  (1.44, DenseVector([-1.42])),
#  (1.03, DenseVector([-0.97])),
#  (-0.05, DenseVector([-0.06])),
#  (0.8, DenseVector([-0.9])),
#  (-0.34, DenseVector([0.25])),
#  (0.69, DenseVector([-0.63])),
#  (-1.67, DenseVector([1.46])),
#  (0.7, DenseVector([-0.55])),
#  (0.5, DenseVector([-0.62])),
#  (-1.08, DenseVector([1.12])),
#  (0.37, DenseVector([-0.36])),
#  (-0.87, DenseVector([0.87])),
#  (1.12, DenseVector([-1.1])),
#  (-0.92, DenseVector([0.95])),
#  (0.26, DenseVector([-0.26])),
#  (0.49, DenseVector([-0.64])),
#  (1.48, DenseVector([-1.49])),
#  (-0.02, DenseVector([-0.08])),
#  (1.11, DenseVector([-1.29])),
#  (-1.66, DenseVector([1.64])),
#  (0.97, DenseVector([-0.92])),
#  (-0.09, DenseVector([0.1])),
#  (0.09, DenseVector([0.01])),
#  (-0.62, DenseVector([0.68])),
#  (-1.75, DenseVector([1.69])),
#  (0.58, DenseVector([-0.57])),
#  (0.86, DenseVector([-0.89])),
#  (1.93, DenseVector([-2.09])),
#  (2.31, DenseVector([-2.3])),
#  (0.16, DenseVector([-0.2])),
#  (0.75, DenseVector([-0.6])),
#  (-0.59, DenseVector([0.39])),
#  (-0.52, DenseVector([0.53])),
#  (0.09, DenseVector([-0.11])),
#  (0.72, DenseVector([-0.91])),
#  (-0.68, DenseVector([0.8])),
#  (1.0, DenseVector([-0.97])),
#  (-0.6, DenseVector([0.56])),
#  (0.84, DenseVector([-0.82])),
#  (0.25, DenseVector([-0.24])),
#  (1.8, DenseVector([-1.79])),
#  (0.08, DenseVector([0.01])),
#  (-0.0, DenseVector([0.03])),
#  (-0.49, DenseVector([0.44])),
#  (0.65, DenseVector([-0.54])),
#  (-0.46, DenseVector([0.64])),
#  (-0.29, DenseVector([0.34])),
#  (0.42, DenseVector([-0.29])),
#  (-0.53, DenseVector([0.51])),
#  (0.17, DenseVector([-0.38])),
#  (-0.95, DenseVector([0.84])),
#  (2.09, DenseVector([-2.14])),
#  (-2.36, DenseVector([2.63])),
#  (-0.21, DenseVector([0.36])),
#  (-2.54, DenseVector([2.39])),
#  (-0.16, DenseVector([0.16])),
#  (0.3, DenseVector([-0.29])),
#  (-0.1, DenseVector([0.11])),
#  (0.93, DenseVector([-0.96])),
#  (-1.17, DenseVector([1.25])),
#  (0.02, DenseVector([-0.03])),
#  (-0.25, DenseVector([0.28])),
#  (-0.97, DenseVector([0.91])),
#  (-0.35, DenseVector([0.33])),
#  (-0.71, DenseVector([0.88])),
#  (0.25, DenseVector([-0.09])),
#  (0.0, DenseVector([-0.06])),
#  (-0.07, DenseVector([0.06])),
#  (-0.49, DenseVector([0.65])),
#  (-2.27, DenseVector([2.19])),
#  (0.54, DenseVector([-0.72])),
#  (0.09, DenseVector([-0.02])),
#  (-0.02, DenseVector([-0.04])),
#  (0.13, DenseVector([-0.11])),
#  (-0.33, DenseVector([0.29])),
#  (-1.34, DenseVector([1.3])),
#  (-1.14, DenseVector([1.15])),
#  (0.68, DenseVector([-0.64])),
#  (-0.78, DenseVector([0.81])),
#  (0.9, DenseVector([-0.83])),
#  (-0.19, DenseVector([0.44])),
#  (-0.01, DenseVector([0.19])),
#  (0.49, DenseVector([-0.37])),
#  (0.02, DenseVector([0.01])),
#  (-0.69, DenseVector([0.74])),
#  (-1.2, DenseVector([1.11])),
#  (-0.09, DenseVector([0.16])),
#  (-0.54, DenseVector([0.52])),
#  (1.01, DenseVector([-0.97])),
#  (0.24, DenseVector([-0.27])),
#  (0.55, DenseVector([-0.55])),
#  (0.36, DenseVector([-0.47])),
#  (1.39, DenseVector([-1.38])),
#  (0.63, DenseVector([-0.56])),
#  (0.94, DenseVector([-0.88])),
#  (-1.27, DenseVector([1.19])),
#  (0.58, DenseVector([-0.61])),
#  (0.41, DenseVector([-0.41])),
#  (1.08, DenseVector([-1.08])),
#  (0.42, DenseVector([-0.41])),
#  (-0.61, DenseVector([0.59])),
#  (-1.33, DenseVector([1.48])),
#  (0.07, DenseVector([-0.07])),
#  (-0.05, DenseVector([0.18])),
#  (-0.25, DenseVector([0.22])),
#  (0.77, DenseVector([-0.68])),
#  (0.11, DenseVector([0.05])),
#  (-1.23, DenseVector([1.19])),
#  (-0.28, DenseVector([0.29])),
#  (-1.87, DenseVector([1.98])),
#  (1.5, DenseVector([-1.61])),
#  (0.54, DenseVector([-0.51])),
#  (-0.63, DenseVector([0.61])),
#  (-0.23, DenseVector([0.24])),
#  (-0.16, DenseVector([0.32])),
#  (-0.55, DenseVector([0.64])),
#  (-0.89, DenseVector([0.88])),
#  (-0.22, DenseVector([0.29])),
#  (0.53, DenseVector([-0.49])),
#  (-0.18, DenseVector([0.14])),
#  (1.73, DenseVector([-1.63])),
#  (0.67, DenseVector([-0.73])),
#  (0.42, DenseVector([-0.43])),
#  (0.43, DenseVector([-0.42])),
#  (-0.57, DenseVector([0.54])),
#  (-0.32, DenseVector([0.21])),
#  (1.41, DenseVector([-1.21])),
#  (-0.17, DenseVector([0.19])),
#  (-0.02, DenseVector([-0.04])),
#  (-1.64, DenseVector([1.84])),
#  (0.34, DenseVector([-0.4])),
#  (0.82, DenseVector([-0.83])),
#  (-0.1, DenseVector([0.01])),
#  (-1.47, DenseVector([1.46])),
#  (-1.25, DenseVector([1.32])),
#  (-0.26, DenseVector([0.11])),
#  (0.89, DenseVector([-0.63])),
#  (-0.1, DenseVector([0.05])),
#  (0.26, DenseVector([-0.2])),
#  (-1.8, DenseVector([1.84])),
#  (0.96, DenseVector([-1.08])),
#  (0.45, DenseVector([-0.42])),
#  (0.39, DenseVector([-0.29])),
#  (1.37, DenseVector([-1.41])),
#  (-1.94, DenseVector([1.94])),
#  (2.14, DenseVector([-2.19])),
#  (0.45, DenseVector([-0.41])),
#  (-0.84, DenseVector([0.89])),
#  (-0.3, DenseVector([0.35])),
#  (-1.03, DenseVector([1.07])),
#  (1.76, DenseVector([-1.87])),
#  (1.16, DenseVector([-1.22])),
#  (-0.48, DenseVector([0.55])),
#  (-1.29, DenseVector([1.14])),
#  (-0.16, DenseVector([0.14])),
#  (0.23, DenseVector([-0.3])),
#  (0.05, DenseVector([-0.02])),
#  (-0.1, DenseVector([0.13])),
#  (-0.19, DenseVector([0.29])),
#  (1.54, DenseVector([-1.53])),
#  (0.28, DenseVector([-0.35])),
#  (0.59, DenseVector([-0.6])),
#  (-1.37, DenseVector([1.25])),
#  (-0.8, DenseVector([0.8])),
#  (-1.1, DenseVector([1.08])),
#  (0.96, DenseVector([-0.84])),
#  (0.5, DenseVector([-0.48])),
#  (-0.24, DenseVector([0.24])),
#  (-0.94, DenseVector([1.02])),
#  (-0.51, DenseVector([0.34])),
#  (0.33, DenseVector([-0.17])),
#  (-0.1, DenseVector([0.26])),
#  (-1.63, DenseVector([1.58])),
#  (-0.72, DenseVector([0.84])),
#  (-0.42, DenseVector([0.36])),
#  (0.37, DenseVector([-0.47])),
#  (-1.58, DenseVector([1.65])),
#  (-0.32, DenseVector([0.25])),
#  (-1.5, DenseVector([1.38])),
#  (-0.14, DenseVector([0.22])),
#  (-1.83, DenseVector([1.68])),
#  (-2.6, DenseVector([2.58])),
#  (-0.1, DenseVector([0.1])),
#  (0.98, DenseVector([-0.99])),
#  (-0.31, DenseVector([0.26])),
#  (-0.98, DenseVector([1.18])),
#  (0.13, DenseVector([-0.15])),
#  (-1.35, DenseVector([1.24])),
#  (-0.61, DenseVector([0.63])),
#  (0.06, DenseVector([-0.14])),
#  (0.9, DenseVector([-0.72])),
#  (-1.54, DenseVector([1.75])),
#  (-0.72, DenseVector([0.67])),
#  (0.48, DenseVector([-0.58])),
#  (0.5, DenseVector([-0.65])),
#  (-0.21, DenseVector([0.33])),
#  (-1.57, DenseVector([1.43])),
#  (-1.37, DenseVector([1.35])),
#  (-0.35, DenseVector([0.42])),
#  (-0.2, DenseVector([0.3])),
#  (-1.08, DenseVector([1.1])),
#  (0.64, DenseVector([-0.48])),
#  (-1.8, DenseVector([1.8])),
#  (-1.6, DenseVector([1.54])),
#  (-0.38, DenseVector([0.17])),
#  (-0.3, DenseVector([0.16])),
#  (-0.15, DenseVector([0.18])),
#  (0.95, DenseVector([-0.89])),
#  (0.45, DenseVector([-0.63])),
#  (-1.68, DenseVector([1.57])),
#  (-0.55, DenseVector([0.69])),
#  (0.17, DenseVector([-0.02])),
#  (1.52, DenseVector([-1.52])),
#  (2.08, DenseVector([-2.22])),
#  (1.31, DenseVector([-1.33])),
#  (0.38, DenseVector([-0.26])),
#  (-0.01, DenseVector([0.09])),
#  (-1.66, DenseVector([1.71])),
#  (-0.3, DenseVector([0.18])),
#  (-0.96, DenseVector([0.98])),
#  (-0.93, DenseVector([0.8])),
#  (-0.79, DenseVector([0.82])),
#  (1.0, DenseVector([-1.04])),
#  (-1.02, DenseVector([0.96])),
#  (-0.35, DenseVector([0.4])),
#  (0.78, DenseVector([-0.81])),
#  (-0.92, DenseVector([1.02])),
#  (-3.23, DenseVector([3.26])),
#  (0.34, DenseVector([-0.27])),
#  (0.45, DenseVector([-0.65])),
#  (0.14, DenseVector([-0.31])),
#  (-1.68, DenseVector([1.71])),
#  (-0.81, DenseVector([0.73])),
#  (-0.05, DenseVector([0.01])),
#  (-1.14, DenseVector([0.91])),
#  (1.86, DenseVector([-1.87])),
#  (-0.4, DenseVector([0.46])),
#  (-0.26, DenseVector([0.54])),
#  (-1.59, DenseVector([1.59])),
#  (0.86, DenseVector([-1.08])),
#  (0.72, DenseVector([-0.78])),
#  (0.49, DenseVector([-0.52])),
#  (0.89, DenseVector([-0.98])),
#  (-1.2, DenseVector([1.36])),
#  (0.02, DenseVector([0.0])),
#  (0.32, DenseVector([-0.38])),
#  (-0.88, DenseVector([0.73])),
#  (-0.0, DenseVector([-0.1])),
#  (-1.98, DenseVector([2.1])),
#  (-1.25, DenseVector([1.23])),
#  (2.27, DenseVector([-2.32])),
#  (1.14, DenseVector([-1.06])),
#  (0.26, DenseVector([-0.29])),
#  (-0.98, DenseVector([1.04])),
#  (0.53, DenseVector([-0.28])),
#  (-1.0, DenseVector([0.87])),
#  (0.56, DenseVector([-0.58])),
#  (-1.01, DenseVector([1.17])),
#  (0.69, DenseVector([-0.6])),
#  (1.02, DenseVector([-1.05])),
#  (0.61, DenseVector([-0.75])),
#  (0.51, DenseVector([-0.31])),
#  (0.1, DenseVector([-0.12])),
#  (0.53, DenseVector([-0.44])),
#  (-1.5, DenseVector([1.4])),
#  (1.59, DenseVector([-1.58])),
#  (-0.48, DenseVector([0.69])),
#  (-0.4, DenseVector([0.56])),
#  (-0.36, DenseVector([0.48])),
#  (-0.97, DenseVector([0.79])),
#  (-1.4, DenseVector([1.46])),
#  (1.86, DenseVector([-1.87])),
#  (1.09, DenseVector([-1.05])),
#  (-0.73, DenseVector([0.67])),
#  (1.13, DenseVector([-1.34])),
#  (1.04, DenseVector([-0.89])),
#  (-0.02, DenseVector([-0.11])),
#  (0.15, DenseVector([-0.27])),
#  (-0.75, DenseVector([0.65])),
#  (1.47, DenseVector([-1.29])),
#  (-1.15, DenseVector([1.29])),
#  (-0.25, DenseVector([0.39])),
#  (1.04, DenseVector([-1.05])),
#  (-2.89, DenseVector([2.89])),
#  (0.55, DenseVector([-0.44])),
#  (0.55, DenseVector([-0.33])),
#  (0.95, DenseVector([-0.95])),
#  (-0.61, DenseVector([0.74])),
#  (-0.15, DenseVector([0.23])),
#  (-0.93, DenseVector([0.91])),
#  (-0.54, DenseVector([0.63])),
#  (-0.78, DenseVector([0.95])),
#  (-0.41, DenseVector([0.41])),
#  (-1.35, DenseVector([1.19])),
#  (1.82, DenseVector([-1.71])),
#  (0.25, DenseVector([-0.19])),
#  (-1.08, DenseVector([1.18])),
#  (-0.31, DenseVector([0.21])),
#  (-0.92, DenseVector([1.0])),
#  (0.95, DenseVector([-1.05])),
#  (2.0, DenseVector([-1.85])),
#  (-1.7, DenseVector([1.79])),
#  (-0.6, DenseVector([0.53])),
#  (0.74, DenseVector([-0.6])),
#  (-0.18, DenseVector([0.09])),
#  (-0.2, DenseVector([0.33])),
#  (0.65, DenseVector([-0.6])),
#  (-2.14, DenseVector([2.09])),
#  (-1.35, DenseVector([1.43])),
#  (-1.01, DenseVector([0.84])),
#  (1.1, DenseVector([-0.95])),
#  (-0.31, DenseVector([0.25])),
#  (1.13, DenseVector([-1.25])),
#  (-1.03, DenseVector([0.88])),
#  (1.25, DenseVector([-1.33])),
#  (-0.19, DenseVector([0.21])),
#  (-0.9, DenseVector([0.89])),
#  (1.01, DenseVector([-0.94])),
#  (-1.34, DenseVector([1.33])),
#  (-1.23, DenseVector([1.09])),
#  (1.5, DenseVector([-1.56])),
#  (0.44, DenseVector([-0.38])),
#  (-1.01, DenseVector([1.08])),
#  (0.69, DenseVector([-0.62])),
#  (0.78, DenseVector([-0.78])),
#  (-0.21, DenseVector([0.14])),
#  (0.11, DenseVector([-0.14])),
#  (0.99, DenseVector([-0.88])),
#  (-0.91, DenseVector([1.02])),
#  (2.67, DenseVector([-2.51])),
#  (-1.4, DenseVector([1.3])),
#  (-0.11, DenseVector([0.27])),
#  (0.38, DenseVector([-0.33])),
#  (0.49, DenseVector([-0.45])),
#  (-0.18, DenseVector([-0.01])),
#  (0.77, DenseVector([-0.74])),
#  (2.62, DenseVector([-2.69])),
#  (-0.54, DenseVector([0.4])),
#  (-0.56, DenseVector([0.78])),
#  (-1.97, DenseVector([1.85])),
#  (0.31, DenseVector([-0.31])),
#  (0.08, DenseVector([-0.08])),
#  (-0.37, DenseVector([0.61])),
#  (-0.41, DenseVector([0.32])),
#  (1.65, DenseVector([-1.57])),
#  (1.54, DenseVector([-1.72])),
#  (-0.09, DenseVector([0.01])),
#  (-0.8, DenseVector([0.8])),
#  (-0.7, DenseVector([0.55])),
#  (-1.41, DenseVector([1.23])),
#  (0.03, DenseVector([0.02])),
#  (0.25, DenseVector([-0.24])),
#  (-0.85, DenseVector([0.85])),
#  (-0.04, DenseVector([0.23])),
#  (0.05, DenseVector([-0.16])),
#  (-0.54, DenseVector([0.49])),
#  (-0.6, DenseVector([0.35])),
#  (-0.91, DenseVector([0.71])),
#  (-0.34, DenseVector([0.32])),
#  (0.41, DenseVector([-0.44])),
#  (-1.38, DenseVector([1.23])),
#  (0.89, DenseVector([-0.83])),
#  (-0.19, DenseVector([0.16])),
#  (0.06, DenseVector([-0.18])),
#  (1.74, DenseVector([-1.56])),
#  (0.36, DenseVector([-0.43])),
#  (-2.22, DenseVector([2.15])),
#  (0.93, DenseVector([-0.93])),
#  (0.86, DenseVector([-0.96])),
#  (-0.7, DenseVector([0.76])),
#  (-0.99, DenseVector([1.08])),
#  (-0.47, DenseVector([0.47])),
#  (-0.72, DenseVector([0.59])),
#  (-0.18, DenseVector([0.31])),
#  (1.34, DenseVector([-1.31])),
#  (0.12, DenseVector([0.01])),
#  (1.2, DenseVector([-1.2])),
#  (0.78, DenseVector([-0.69])),
#  (1.38, DenseVector([-1.33])),
#  (-0.06, DenseVector([-0.02])),
#  (1.95, DenseVector([-2.1])),
#  (-0.42, DenseVector([0.46])),
#  (-0.11, DenseVector([0.04])),
#  (0.7, DenseVector([-0.82])),
#  (1.05, DenseVector([-1.01])),
#  (-1.09, DenseVector([1.04])),
#  (1.36, DenseVector([-1.46])),
#  (0.1, DenseVector([0.2])),
#  (-1.18, DenseVector([1.23])),
#  (-1.91, DenseVector([1.95])),
#  (0.68, DenseVector([-0.84])),
#  (-2.36, DenseVector([2.43])),
#  (1.31, DenseVector([-1.28])),
#  (-0.97, DenseVector([1.04])),
#  (0.18, DenseVector([-0.07])),
#  (-0.77, DenseVector([0.94])),
#  (0.68, DenseVector([-0.63])),
#  (-0.85, DenseVector([0.83])),
#  (1.93, DenseVector([-1.71])),
#  (-0.91, DenseVector([0.86])),
#  (1.53, DenseVector([-1.75])),
#  (-0.79, DenseVector([0.91])),
#  (1.56, DenseVector([-1.62])),
#  (-0.0, DenseVector([-0.06])),
#  (1.01, DenseVector([-0.9])),
#  (1.16, DenseVector([-1.15])),
#  (0.73, DenseVector([-0.7])),
#  (1.05, DenseVector([-0.88])),
#  (1.54, DenseVector([-1.6])),
#  (0.05, DenseVector([-0.06])),
#  (-1.16, DenseVector([1.12])),
#  (-0.62, DenseVector([0.59])),
#  (0.63, DenseVector([-0.7])),
#  (0.11, DenseVector([-0.01])),
#  (-0.42, DenseVector([0.49])),
#  (0.34, DenseVector([-0.2])),
#  (0.16, DenseVector([-0.31])),
#  (-0.11, DenseVector([0.15])),
#  (0.97, DenseVector([-0.84])),
#  (0.03, DenseVector([-0.1])),
#  (1.19, DenseVector([-1.19])),
#  (0.3, DenseVector([-0.21])),
#  (-0.05, DenseVector([0.02])),
#  (-0.39, DenseVector([0.22])),
#  (1.05, DenseVector([-1.08])),
#  (-1.45, DenseVector([1.52])),
#  (-0.25, DenseVector([0.29])),
#  (1.98, DenseVector([-2.06])),
#  (0.82, DenseVector([-0.73])),
#  (-0.71, DenseVector([0.62])),
#  (-0.13, DenseVector([0.16])),
#  (-0.73, DenseVector([0.54])),
#  (-0.95, DenseVector([0.96])),
#  (0.42, DenseVector([-0.46])),
#  (1.76, DenseVector([-1.73])),
#  (-1.3, DenseVector([1.11])),
#  (0.4, DenseVector([-0.51])),
#  (1.85, DenseVector([-1.81])),
#  (0.73, DenseVector([-0.68])),
#  (-1.68, DenseVector([1.75])),
#  (0.61, DenseVector([-0.56])),
#  (1.8, DenseVector([-1.69])),
#  (-1.2, DenseVector([1.31])),
#  (-0.55, DenseVector([0.48])),
#  (-1.27, DenseVector([1.2])),
#  (-1.24, DenseVector([1.17])),
#  (0.24, DenseVector([-0.22])),
#  (0.6, DenseVector([-0.69])),
#  (0.91, DenseVector([-0.95])),
#  (-0.3, DenseVector([0.4])),
#  (-0.44, DenseVector([0.43])),
#  (0.03, DenseVector([0.03])),
#  (1.44, DenseVector([-1.27])),
#  (0.55, DenseVector([-0.48])),
#  (-0.33, DenseVector([0.25])),
#  (-0.18, DenseVector([0.1])),
#  (1.08, DenseVector([-1.11])),
#  (-1.17, DenseVector([1.12])),
#  (-1.36, DenseVector([1.37])),
#  (1.82, DenseVector([-1.76])),
#  (-0.4, DenseVector([0.37])),
#  (-0.44, DenseVector([0.45])),
#  (0.29, DenseVector([-0.23])),
#  (0.13, DenseVector([-0.07])),
#  (-1.84, DenseVector([1.9])),
#  (0.1, DenseVector([-0.22])),
#  (-0.62, DenseVector([0.6])),
#  (0.95, DenseVector([-1.04])),
#  (0.75, DenseVector([-0.85])),
#  (-0.28, DenseVector([0.33])),
#  (-0.05, DenseVector([-0.11])),
#  (-1.39, DenseVector([1.44])),
#  (-0.39, DenseVector([0.45])),
#  (1.82, DenseVector([-1.84])),
#  (-1.66, DenseVector([1.61])),
#  (0.29, DenseVector([-0.27])),
#  (0.34, DenseVector([-0.52])),
#  (-0.13, DenseVector([0.04])),
#  (-0.07, DenseVector([0.07])),
#  (-0.41, DenseVector([0.27])),
#  (-1.0, DenseVector([1.0])),
#  (0.32, DenseVector([-0.2])),
#  (0.9, DenseVector([-0.9])),
#  (-0.2, DenseVector([0.06])),
#  (-0.75, DenseVector([0.8])),
#  (0.85, DenseVector([-0.74])),
#  (-0.34, DenseVector([0.39])),
#  (0.3, DenseVector([-0.26])),
#  (-0.28, DenseVector([0.36])),
#  (0.31, DenseVector([-0.31])),
#  (0.45, DenseVector([-0.52])),
#  (1.17, DenseVector([-1.21])),
#  (-0.11, DenseVector([0.12])),
#  (0.67, DenseVector([-0.8])),
#  (-0.9, DenseVector([0.78])),
#  (0.01, DenseVector([-0.15])),
#  (-0.21, DenseVector([0.32])),
#  (1.4, DenseVector([-1.59])),
#  (0.74, DenseVector([-0.78])),
#  (1.27, DenseVector([-1.2])),
#  (-0.4, DenseVector([0.3])),
#  (-0.59, DenseVector([0.54])),
#  (-0.81, DenseVector([0.86])),
#  (-0.3, DenseVector([0.16])),
#  (-0.2, DenseVector([0.28])),
#  (0.56, DenseVector([-0.39])),
#  (0.15, DenseVector([-0.26])),
#  (-0.93, DenseVector([1.06])),
#  (0.9, DenseVector([-0.92])),
#  (1.17, DenseVector([-1.4])),
#  (0.84, DenseVector([-0.59])),
#  (2.71, DenseVector([-2.9])),
#  (-0.19, DenseVector([0.16])),
#  (0.93, DenseVector([-0.96])),
#  (-0.02, DenseVector([-0.12])),
#  (-0.88, DenseVector([0.81])),
#  (0.45, DenseVector([-0.47])),
#  (1.29, DenseVector([-1.43])),
#  (1.16, DenseVector([-1.05])),
#  (1.55, DenseVector([-1.6])),
#  (0.27, DenseVector([-0.33])),
#  (0.48, DenseVector([-0.58])),
#  (1.19, DenseVector([-1.12])),
#  (1.09, DenseVector([-1.11])),
#  (0.38, DenseVector([-0.39])),
#  (-0.64, DenseVector([0.62])),
#  (1.74, DenseVector([-1.52])),
#  (0.98, DenseVector([-1.15])),
#  (-0.3, DenseVector([0.41])),
#  (0.35, DenseVector([-0.5])),
#  (-0.59, DenseVector([0.6])),
#  (-0.69, DenseVector([0.57])),
#  (-1.36, DenseVector([1.25])),
#  (-0.56, DenseVector([0.64])),
#  (0.18, DenseVector([-0.21])),
#  (-0.16, DenseVector([0.02])),
#  (0.63, DenseVector([-0.65])),
#  (-0.74, DenseVector([0.68])),
#  (-0.44, DenseVector([0.5])),
#  (0.68, DenseVector([-0.74])),
#  (1.69, DenseVector([-1.66])),
#  (-1.66, DenseVector([1.77])),
#  (0.21, DenseVector([-0.18])),
#  (0.22, DenseVector([-0.32])),
#  (-0.14, DenseVector([0.29])),
#  (-0.63, DenseVector([0.55])),
#  (-0.81, DenseVector([0.83])),
#  (-0.37, DenseVector([0.37])),
#  (-1.54, DenseVector([1.61])),
#  (-0.29, DenseVector([0.41])),
#  (1.78, DenseVector([-1.77])),
#  (-1.1, DenseVector([1.07])),
#  (-0.73, DenseVector([0.63])),
#  (0.35, DenseVector([-0.13])),
#  (-0.05, DenseVector([0.09])),
#  (-0.07, DenseVector([0.02])),
#  (2.76, DenseVector([-2.8])),
#  (-0.37, DenseVector([0.44])),
#  (0.14, DenseVector([-0.08])),
#  (-0.12, DenseVector([-0.03])),
#  (0.24, DenseVector([-0.3])),
#  (-1.42, DenseVector([1.48])),
#  (0.9, DenseVector([-0.96])),
#  (-1.25, DenseVector([1.2])),
#  (-2.54, DenseVector([2.49])),
#  (-0.48, DenseVector([0.57])),
#  (0.96, DenseVector([-1.05])),
#  (-3.54, DenseVector([3.44])),
#  (-0.02, DenseVector([0.14])),
#  (-0.24, DenseVector([0.06])),
#  (-2.45, DenseVector([2.44])),
#  (1.61, DenseVector([-1.64])),
#  (1.45, DenseVector([-1.5])),
#  (-0.71, DenseVector([0.68])),
#  (1.13, DenseVector([-1.08])),
#  (0.45, DenseVector([-0.31])),
#  (-0.25, DenseVector([0.26])),
#  (-0.52, DenseVector([0.56])),
#  (-0.32, DenseVector([0.36])),
#  (-0.82, DenseVector([1.04])),
#  (0.67, DenseVector([-0.64])),
#  (0.78, DenseVector([-0.8])),
#  (1.35, DenseVector([-1.35])),
#  (0.99, DenseVector([-1.0])),
#  (-0.3, DenseVector([0.28])),
#  (-0.14, DenseVector([0.38])),
#  (0.1, DenseVector([-0.07])),
#  (-0.57, DenseVector([0.42])),
#  (0.45, DenseVector([-0.56])),
#  (1.53, DenseVector([-1.45])),
#  (0.41, DenseVector([-0.55])),
#  (0.22, DenseVector([-0.38])),
#  (1.26, DenseVector([-1.31])),
#  (0.65, DenseVector([-0.64])),
#  (1.28, DenseVector([-1.2])),
#  (-0.73, DenseVector([0.74])),
#  (0.11, DenseVector([-0.04])),
#  (-1.82, DenseVector([1.85])),
#  (-0.4, DenseVector([0.22])),
#  (0.55, DenseVector([-0.66])),
#  (-1.16, DenseVector([0.97])),
#  (-0.19, DenseVector([0.12])),
#  (-2.06, DenseVector([1.95])),
#  (-0.75, DenseVector([0.84])),
#  (0.68, DenseVector([-0.61])),
#  (0.24, DenseVector([-0.28])),
#  (-0.69, DenseVector([0.73])),
#  (1.0, DenseVector([-1.08])),
#  (-0.58, DenseVector([0.77])),
#  (-0.48, DenseVector([0.34])),
#  (-0.81, DenseVector([0.95])),
#  (-0.76, DenseVector([0.87])),
#  (-0.34, DenseVector([0.32])),
#  (1.06, DenseVector([-1.11])),
#  (0.95, DenseVector([-0.86])),
#  (1.41, DenseVector([-1.47])),
#  (0.19, DenseVector([-0.22])),
#  (0.58, DenseVector([-0.51])),
#  (0.19, DenseVector([-0.09])),
#  (0.26, DenseVector([-0.31])),
#  (0.69, DenseVector([-0.81])),
#  (1.53, DenseVector([-1.58])),
#  (0.69, DenseVector([-0.73])),
#  (0.19, DenseVector([-0.2])),
#  (-0.79, DenseVector([0.95])),
#  (0.42, DenseVector([-0.36])),
#  (0.69, DenseVector([-0.87])),
#  (0.87, DenseVector([-1.02])),
#  (0.73, DenseVector([-0.8])),
#  (0.47, DenseVector([-0.34])),
#  (0.4, DenseVector([-0.46])),
#  (-0.63, DenseVector([0.49])),
#  (-0.7, DenseVector([0.77])),
#  (-1.54, DenseVector([1.49])),
#  (1.78, DenseVector([-1.94])),
#  (0.21, DenseVector([-0.36])),
#  (0.38, DenseVector([-0.46])),
#  (1.53, DenseVector([-1.54])),
#  (0.98, DenseVector([-1.06])),
#  (-0.17, DenseVector([0.07])),
#  (-0.89, DenseVector([0.91])),
#  (-0.96, DenseVector([0.89])),
#  (0.05, DenseVector([0.0])),
#  (0.09, DenseVector([-0.14])),
#  (-1.69, DenseVector([1.6])),
#  (-1.3, DenseVector([1.37])),
#  (2.09, DenseVector([-2.08])),
#  (-0.1, DenseVector([0.02])),
#  (1.5, DenseVector([-1.24])),
#  (-0.65, DenseVector([0.73])),
#  (-0.98, DenseVector([0.9])),
#  (-0.35, DenseVector([0.25])),
#  (-0.71, DenseVector([0.72])),
#  (0.88, DenseVector([-0.8])),
#  (-2.0, DenseVector([2.02])),
#  (-1.43, DenseVector([1.38])),
#  (0.81, DenseVector([-0.81])),
#  (-0.75, DenseVector([0.78])),
#  (0.18, DenseVector([-0.39])),
#  (0.08, DenseVector([-0.19])),
#  (-0.12, DenseVector([0.27])),
#  (0.38, DenseVector([-0.52])),
#  (-2.43, DenseVector([2.34])),
#  (-0.02, DenseVector([-0.01])),
#  (0.0, DenseVector([-0.14])),
#  (-0.78, DenseVector([0.94])),
#  (0.51, DenseVector([-0.38])),
#  (-0.28, DenseVector([0.27])),
#  (-0.56, DenseVector([0.41]))]

# %%
# Convert this RDD to a DataFrame
colNames = ["label", "features"]
df = data.toDF(colNames)
df.show()
# Out:
# +-----+--------+
# |label|features|
# +-----+--------+
# |-1.74|  [1.66]|
# | 1.24| [-1.18]|
# | 0.29|  [-0.4]|
# |-0.13|  [0.09]|
# |-0.39|  [0.38]|
# |-1.79|  [1.73]|
# | 0.71| [-0.77]|
# | 1.39| [-1.48]|
# | 1.15| [-1.43]|
# | 0.13| [-0.07]|
# | 0.05| [-0.07]|
# |  1.9|  [-1.8]|
# | 1.48| [-1.42]|
# | 0.32|  [-0.3]|
# |-1.11|   [1.0]|
# | 0.51| [-0.62]|
# |-1.58|  [1.45]|
# |-0.46|  [0.44]|
# |-0.49|  [0.37]|
# | 0.31|  [-0.3]|
# +-----+--------+
# only showing top 20 rows

# %%
trainTest = df.randomSplit([0.5, 0.5])
trainingDF = trainTest[0]
testDF = trainTest[1]

# %%
# Now create our linear regression model
lir = LinearRegression(maxIter=10, regParam=0.3, elasticNetParam=0.8)

# Train the model using our training data
model = lir.fit(trainingDF)

# %%
# Now see if we can predict values in our test data.
# Generate predictions using our linear regression model for all features in our
# test dataframe:
fullPredictions = model.transform(testDF).cache()

# %%
# Extract the predictions and the "known" correct labels.
predictions = fullPredictions.select("prediction").rdd.map(lambda x: x[0])
labels = fullPredictions.select("label").rdd.map(lambda x: x[0])

# %%
# Zip them together
predictionAndLabel = predictions.zip(labels).collect()

# %%
# Print out the predicted and actual values for each point
for prediction in predictionAndLabel:
  print(prediction)
# Out:
# (-2.65901584070991, -3.74)
# (-1.82125458917774, -2.58)
# (-1.594065097236813, -2.26)
# (-1.551467067497889, -2.17)
# (-1.3455765904264236, -2.12)
# (-1.3952742917885015, -2.09)
# (-1.4449719931505796, -2.07)
# (-1.3739752769190396, -1.94)
# (-1.4023739634116557, -1.94)
# (-1.295878889064346, -1.91)
# (-1.4023739634116557, -1.87)
# (-1.3029785606875, -1.8)
# (-1.224882172832806, -1.79)
# (-1.1751844714707282, -1.77)
# (-1.19648348634019, -1.75)
# (-1.1609851282244203, -1.66)
# (-1.3029785606875, -1.64)
# (-1.2177825012096521, -1.61)
# (-1.1467857849781125, -1.59)
# (-1.1680847998475743, -1.58)
# (-1.1041877552391886, -1.57)
# (-0.9763936660224167, -1.48)
# (-1.0331910390076486, -1.47)
# (-0.9976926808918786, -1.46)
# (-0.9337956362834929, -1.4)
# (-0.9337956362834929, -1.39)
# (-0.8840979349214151, -1.37)
# (-0.9976926808918786, -1.36)
# (-0.8060015470667212, -1.3)
# (-0.8344002335593372, -1.3)
# (-0.8060015470667212, -1.29)
# (-1.0402907106308026, -1.29)
# (-0.8273005619361832, -1.26)
# (-0.8485995768056451, -1.22)
# (-0.8485995768056451, -1.2)
# (-0.8840979349214151, -1.17)
# (-0.8131012186898753, -1.14)
# (-0.6498087713573338, -1.1)
# (-0.8344002335593372, -1.09)
# (-0.7918022038204134, -1.08)
# (-0.6427090997341799, -0.97)
# (-0.6782074578499497, -0.97)
# (-0.7492041740814895, -0.96)
# (-0.5717123835026401, -0.95)
# (-0.5930113983721019, -0.95)
# (-0.7208054875888736, -0.94)
# (-0.6711077862267957, -0.92)
# (-0.7279051592120276, -0.91)
# (-0.6214100848647179, -0.89)
# (-0.5433136970100242, -0.88)
# (-0.5646127118794861, -0.85)
# (-0.6427090997341799, -0.85)
# (-0.585911726748948, -0.84)
# (-0.49361599564794634, -0.82)
# (-0.6285097564878719, -0.81)
# (-0.5149150105174082, -0.8)
# (-0.5646127118794861, -0.8)
# (-0.5646127118794861, -0.8)
# (-0.46521730915533044, -0.78)
# (-0.5717123835026401, -0.78)
# (-0.46521730915533044, -0.76)
# (-0.5930113983721019, -0.76)
# (-0.5078153388942542, -0.75)
# (-0.6569084429804878, -0.74)
# (-0.43681862266271454, -0.73)
# (-0.3871209213006367, -0.71)
# (-0.5362140253868701, -0.68)
# (-0.6214100848647179, -0.68)
# (-0.4581176375321765, -0.66)
# (-0.38002124967748274, -0.65)
# (-0.4013202645469446, -0.65)
# (-0.6214100848647179, -0.65)
# (-0.4084199361700986, -0.62)
# (-0.47941665240163844, -0.62)
# (-0.3942205929237907, -0.6)
# (-0.42971895103956054, -0.6)
# (-0.27352617533017304, -0.59)
# (-0.38002124967748274, -0.57)
# (-0.36582190643117474, -0.54)
# (-0.21672880234494118, -0.53)
# (-0.48651632402479233, -0.51)
# (-0.30902453344594294, -0.49)
# (-0.30902453344594294, -0.49)
# (-0.3161242050690969, -0.42)
# (-0.18833011585232529, -0.39)
# (-0.23092814559124913, -0.35)
# (-0.33032354831540484, -0.35)
# (-0.17413077260601734, -0.34)
# (-0.20962913072178718, -0.33)
# (-0.24512748883755708, -0.3)
# (-0.23802781721440314, -0.29)
# (-0.20252945909863324, -0.28)
# (-0.11023372799763152, -0.27)
# (-0.1599314293597094, -0.26)
# (-0.1954297874754793, -0.25)
# (-0.18833011585232529, -0.24)
# (-0.16703110098286333, -0.23)
# (-0.20252945909863324, -0.22)
# (-0.07473536988186164, -0.21)
# (-0.20252945909863324, -0.19)
# (-0.30902453344594294, -0.19)
# (-0.09603438475132357, -0.18)
# (-0.13153274286709343, -0.17)
# (-0.2238284739680952, -0.16)
# (-0.06053602663555367, -0.13)
# (-0.032137340142937766, -0.1)
# (-0.06763569825870766, -0.09)
# (-0.11023372799763152, -0.09)
# (-0.11733339962078551, -0.09)
# (-0.09603438475132357, -0.08)
# (0.06725806258121793, -0.07)
# (0.010460689595986106, -0.07)
# (-0.03923701176609174, -0.07)
# (-0.15283175773655538, -0.07)
# (0.045959047711756, -0.05)
# (0.017560361219140085, -0.05)
# (-0.03923701176609174, -0.05)
# (-0.03923701176609174, -0.05)
# (-0.12443307124393947, -0.05)
# (-0.00373865365032185, -0.04)
# (0.03175970446544804, -0.02)
# (0.05305871933490998, 0.0)
# (0.045959047711756, 0.0)
# (-0.09603438475132357, 0.0)
# (0.024660032842294063, 0.02)
# (0.03175970446544804, 0.03)
# (-0.00373865365032185, 0.04)
# (0.05305871933490998, 0.05)
# (0.017560361219140085, 0.05)
# (-0.00373865365032185, 0.08)
# (-0.025037668519783784, 0.08)
# (0.08145740582752589, 0.09)
# (0.13115510718960371, 0.1)
# (-0.010838325273475828, 0.1)
# (0.11695576394329578, 0.11)
# (0.08145740582752589, 0.13)
# (0.20215182342114352, 0.14)
# (0.08145740582752589, 0.14)
# (0.18795248017483557, 0.15)
# (0.14535445043591172, 0.16)
# (0.045959047711756, 0.16)
# (0.06725806258121793, 0.17)
# (0.18795248017483557, 0.2)
# (0.18085280855168157, 0.21)
# (0.16665346530537362, 0.21)
# (0.16665346530537362, 0.21)
# (0.22345083829060547, 0.22)
# (0.21635116666745147, 0.23)
# (0.19505215179798957, 0.24)
# (0.17375313692852762, 0.25)
# (0.06725806258121793, 0.25)
# (0.20215182342114352, 0.26)
# (0.25184952478322137, 0.28)
# (0.18085280855168157, 0.29)
# (0.20925149504429746, 0.3)
# (0.21635116666745147, 0.31)
# (0.18085280855168157, 0.33)
# (0.28734788289899127, 0.34)
# (0.28734788289899127, 0.34)
# (0.2589491964063753, 0.34)
# (0.24474985316006742, 0.35)
# (0.33704558426106906, 0.36)
# (0.2589491964063753, 0.37)
# (0.20925149504429746, 0.39)
# (0.3228462410147611, 0.4)
# (0.28024821127583727, 0.4)
# (0.2589491964063753, 0.4)
# (0.28024821127583727, 0.41)
# (0.30864689776845317, 0.42)
# (0.20925149504429746, 0.42)
# (0.33704558426106906, 0.43)
# (0.2660488680295293, 0.44)
# (0.30154722614529916, 0.45)
# (0.30864689776845317, 0.46)
# (0.31574656939160717, 0.49)
# (0.44354065860837877, 0.5)
# (0.34414525588422307, 0.5)
# (0.365444270753685, 0.51)
# (0.4009426288694549, 0.53)
# (0.351244927507377, 0.53)
# (0.33704558426106906, 0.53)
# (0.30154722614529916, 0.54)
# (0.48613868834730267, 0.55)
# (0.3938429572463009, 0.55)
# (0.4080423004926088, 0.58)
# (0.42934131536207076, 0.59)
# (0.34414525588422307, 0.61)
# (0.38674328562314697, 0.65)
# (0.3228462410147611, 0.65)
# (0.5074377032167646, 0.66)
# (0.5216370464630725, 0.67)
# (0.5216370464630725, 0.69)
# (0.6494311356798442, 0.72)
# (0.47193934510099467, 0.74)
# (0.4151419721157628, 0.74)
# (0.6565308073029982, 0.75)
# (0.42934131536207076, 0.75)
# (0.5713347478251505, 0.76)
# (0.5500357329556885, 0.76)
# (0.4648396734778407, 0.81)
# (0.6352317924335362, 0.86)
# (0.4506403302315327, 0.89)
# (0.5926337626946123, 0.9)
# (0.6068331059409203, 0.93)
# (0.5642350762019964, 0.93)
# (0.6281321208103823, 0.94)
# (0.5642350762019964, 0.95)
# (0.699128837041922, 0.97)
# (0.6565308073029982, 0.97)
# (0.6068331059409203, 0.97)
# (0.692029165418768, 1.01)
# (0.8198232546355396, 1.05)
# (0.5713347478251505, 1.05)
# (0.7559262100271539, 1.07)
# (0.7701255532734619, 1.08)
# (0.706228508665076, 1.1)
# (0.9192186573596953, 1.11)
# (0.8269229262586936, 1.11)
# (0.8624212843744635, 1.14)
# (0.7772252248966158, 1.14)
# (1.018614060083851, 1.15)
# (0.8198232546355396, 1.2)
# (0.8411222695050016, 1.24)
# (0.8340225978818475, 1.27)
# (0.7914245681429238, 1.27)
# (0.9050193141133874, 1.28)
# (1.0896107763153908, 1.32)
# (1.0044147168375428, 1.37)
# (1.0541124181996209, 1.39)
# (0.9831157019680811, 1.39)
# (1.0612120898227748, 1.48)
# (1.1464081493006226, 1.5)
# (1.1464081493006226, 1.51)
# (1.0825111046922367, 1.54)
# (0.8766206276207714, 1.55)
# (1.2600028952710862, 1.59)
# (1.281301910140548, 1.62)
# (1.1535078209237766, 1.63)
# (1.0683117614459288, 1.63)
# (1.0683117614459288, 1.64)
# (1.3451989547489338, 1.72)
# (1.2103051939090084, 1.83)
# (1.281301910140548, 1.9)
# (1.5226907453277834, 2.09)
# (1.4374946858499356, 2.17)
# (1.5936874615593233, 2.25)
# (1.636285491298247, 2.31)
# (-2.4389260203921364, -3.54)
# (-2.0484440811186677, -2.89)
# (-1.8283542608008942, -2.6)
# (-1.7289588580767385, -2.45)
# (-1.5230683810052732, -2.22)
# (-1.4307726499042714, -2.0)
# (-1.310078232310654, -1.97)
# (-1.3455765904264236, -1.84)
# (-1.1112874268623425, -1.68)
# (-1.2106828295864982, -1.68)
# (-1.2390815160791142, -1.68)
# (-1.2106828295864982, -1.66)
# (-1.1183870984854964, -1.63)
# (-1.0899884119928807, -1.6)
# (-1.2390815160791142, -1.54)
# (-0.9763936660224167, -1.5)
# (-0.9905930092687247, -1.5)
# (-0.9763936660224167, -1.43)
# (-0.919596293037185, -1.4)
# (-0.9692939943992629, -1.36)
# (-0.8769982632982611, -1.35)
# (-0.940895307906647, -1.34)
# (-0.9692939943992629, -1.3)
# (-0.8273005619361832, -1.24)
# (-0.8698985916751071, -1.18)
# (-0.7918022038204134, -1.16)
# (-0.6427090997341799, -1.14)
# (-0.7563038457046435, -1.1)
# (-0.7350048308351815, -1.09)
# (-0.8344002335593372, -1.08)
# (-0.6214100848647179, -1.03)
# (-0.7634035173277975, -1.01)
# (-0.8273005619361832, -1.01)
# (-0.7066061443425656, -1.0)
# (-0.7634035173277975, -0.99)
# (-0.6285097564878719, -0.96)
# (-0.5646127118794861, -0.93)
# (-0.7492041740814895, -0.93)
# (-0.7066061443425656, -0.92)
# (-0.7208054875888736, -0.92)
# (-0.5007156672711003, -0.91)
# (-0.6072107416184099, -0.91)
# (-0.5504133686331781, -0.9)
# (-0.6285097564878719, -0.9)
# (-0.5149150105174082, -0.88)
# (-0.7350048308351815, -0.82)
# (-0.5149150105174082, -0.81)
# (-0.585911726748948, -0.81)
# (-0.6072107416184099, -0.81)
# (-0.6711077862267957, -0.81)
# (-0.5646127118794861, -0.8)
# (-0.6427090997341799, -0.79)
# (-0.6711077862267957, -0.78)
# (-0.6143104132415639, -0.76)
# (-0.5930113983721019, -0.75)
# (-0.47941665240163844, -0.74)
# (-0.38002124967748274, -0.73)
# (-0.4439182942858685, -0.73)
# (-0.5220146821405622, -0.73)
# (-0.3871209213006367, -0.7)
# (-0.5433136970100242, -0.7)
# (-0.5149150105174082, -0.65)
# (-0.43681862266271454, -0.64)
# (-0.3871209213006367, -0.63)
# (-0.42261927941640653, -0.62)
# (-0.4439182942858685, -0.61)
# (-0.37292157805432874, -0.6)
# (-0.29482519019963493, -0.57)
# (-0.4510179659090225, -0.56)
# (-0.33742321993855884, -0.55)
# (-0.28062584695332704, -0.54)
# (-0.48651632402479233, -0.48)
# (-0.33032354831540484, -0.47)
# (-0.3161242050690969, -0.44)
# (-0.3516225631848668, -0.44)
# (-0.3232238766922509, -0.42)
# (-0.3445228915617128, -0.42)
# (-0.18833011585232529, -0.41)
# (-0.15283175773655538, -0.4)
# (-0.3942205929237907, -0.4)
# (-0.15283175773655538, -0.39)
# (-0.3161242050690969, -0.39)
# (-0.11733339962078551, -0.38)
# (-0.30902453344594294, -0.37)
# (-0.42971895103956054, -0.37)
# (-0.33742321993855884, -0.36)
# (-0.17413077260601734, -0.35)
# (-0.2238284739680952, -0.34)
# (-0.2238284739680952, -0.34)
# (-0.27352617533017304, -0.34)
# (-0.17413077260601734, -0.32)
# (-0.1954297874754793, -0.3)
# (-0.28062584695332704, -0.3)
# (-0.287725518576481, -0.29)
# (-0.38002124967748274, -0.26)
# (-0.20252945909863324, -0.25)
# (-0.09603438475132357, -0.21)
# (-0.23092814559124913, -0.21)
# (-0.03923701176609174, -0.2)
# (-0.1954297874754793, -0.2)
# (-0.20962913072178718, -0.2)
# (-0.08183504150501561, -0.19)
# (-0.11023372799763152, -0.19)
# (-0.11023372799763152, -0.19)
# (-0.14573208611340138, -0.19)
# (-0.06053602663555367, -0.18)
# (-0.21672880234494118, -0.18)
# (-0.010838325273475828, -0.16)
# (-0.12443307124393947, -0.15)
# (-0.1599314293597094, -0.15)
# (-0.20252945909863324, -0.14)
# (-0.26642650370701904, -0.14)
# (-0.025037668519783784, -0.13)
# (-0.11023372799763152, -0.13)
# (-0.18833011585232529, -0.12)
# (-0.025037668519783784, -0.11)
# (-0.10313405637447753, -0.11)
# (-0.18833011585232529, -0.11)
# (-0.06763569825870766, -0.1)
# (-0.18123044422917128, -0.1)
# (-0.00373865365032185, -0.09)
# (-0.010838325273475828, -0.07)
# (0.08145740582752589, -0.05)
# (-0.1599314293597094, -0.04)
# (-0.06053602663555367, -0.01)
# (0.045959047711756, -0.0)
# (0.0033610179728321282, 0.02)
# (0.07435773420437192, 0.03)
# (-0.017937996896629806, 0.03)
# (0.13115510718960371, 0.06)
# (0.10275642069698783, 0.06)
# (0.13825477881275772, 0.08)
# (0.15955379368221967, 0.1)
# (0.08855707745067987, 0.1)
# (0.10275642069698783, 0.11)
# (0.03175970446544804, 0.11)
# (-0.00373865365032185, 0.12)
# (0.22345083829060547, 0.14)
# (0.060158390958063954, 0.14)
# (0.017560361219140085, 0.17)
# (0.28024821127583727, 0.18)
# (0.05305871933490998, 0.18)
# (0.15955379368221967, 0.19)
# (0.06725806258121793, 0.19)
# (0.2589491964063753, 0.21)
# (0.13115510718960371, 0.21)
# (0.27314853965268326, 0.22)
# (0.23055050991375942, 0.22)
# (0.20215182342114352, 0.24)
# (0.15955379368221967, 0.24)
# (0.17375313692852762, 0.25)
# (0.19505215179798957, 0.29)
# (0.18795248017483557, 0.3)
# (0.22345083829060547, 0.31)
# (0.27314853965268326, 0.32)
# (0.14535445043591172, 0.32)
# (0.12405543556644977, 0.33)
# (0.37254394237683897, 0.34)
# (0.358344599130531, 0.35)
# (0.09565674907383384, 0.35)
# (0.33704558426106906, 0.37)
# (0.37254394237683897, 0.38)
# (0.3299459126379151, 0.38)
# (0.28024821127583727, 0.38)
# (0.3299459126379151, 0.4)
# (0.27314853965268326, 0.44)
# (0.4648396734778407, 0.45)
# (0.4506403302315327, 0.45)
# (0.33704558426106906, 0.45)
# (0.22345083829060547, 0.51)
# (0.20215182342114352, 0.53)
# (0.23765018153691342, 0.55)
# (0.49323835997045656, 0.6)
# (0.5358363897093805, 0.61)
# (0.4009426288694549, 0.61)
# (0.5003380315936106, 0.63)
# (0.4648396734778407, 0.63)
# (0.34414525588422307, 0.64)
# (0.4577400018546867, 0.65)
# (0.5713347478251505, 0.67)
# (0.5997334343177663, 0.68)
# (0.5287367180862266, 0.68)
# (0.4506403302315327, 0.68)
# (0.6210324491872282, 0.69)
# (0.5216370464630725, 0.69)
# (0.5855340910714584, 0.7)
# (0.5003380315936106, 0.73)
# (0.5571354045788425, 0.74)
# (0.42934131536207076, 0.74)
# (0.6068331059409203, 0.75)
# (0.5287367180862266, 0.77)
# (0.5713347478251505, 0.78)
# (0.49323835997045656, 0.78)
# (0.5784344194483044, 0.81)
# (0.6849294937956141, 0.86)
# (0.727527523534538, 0.87)
# (0.5713347478251505, 0.88)
# (0.6565308073029982, 0.9)
# (0.6423314640566902, 0.9)
# (0.5145373748399186, 0.9)
# (0.6849294937956141, 0.93)
# (0.7488265384039999, 0.95)
# (0.7417268667808459, 0.95)
# (0.6352317924335362, 0.95)
# (0.6139327775640743, 0.95)
# (0.7488265384039999, 0.96)
# (0.8198232546355396, 0.98)
# (0.71332818028823, 0.99)
# (0.6281321208103823, 0.99)
# (0.7701255532734619, 1.0)
# (0.7417268667808459, 1.0)
# (0.6707301505493061, 1.01)
# (0.6423314640566902, 1.01)
# (0.7488265384039999, 1.02)
# (0.7488265384039999, 1.04)
# (0.7204278519113839, 1.05)
# (0.6281321208103823, 1.05)
# (0.7914245681429238, 1.06)
# (0.7914245681429238, 1.08)
# (0.67782982217246, 1.1)
# (0.8908199708670794, 1.13)
# (0.8624212843744635, 1.17)
# (0.7985242397660778, 1.19)
# (0.8553216127513095, 1.2)
# (0.9476173438523113, 1.25)
# (0.8553216127513095, 1.28)
# (0.9476173438523113, 1.38)
# (1.0470127465764667, 1.41)
# (1.1109097911848527, 1.5)
# (1.2458035520247783, 1.53)
# (1.1251091344311606, 1.53)
# (1.0328134033301588, 1.53)
# (1.2245045371553163, 1.54)
# (1.1393084776774687, 1.54)
# (1.1535078209237766, 1.56)
# (1.1677071641700845, 1.61)
# (1.1180094628080066, 1.65)
# (1.0825111046922367, 1.74)
# (1.3806973128647038, 1.78)
# (1.2600028952710862, 1.78)
# (1.2032055222858542, 1.8)
# (1.309700596633164, 1.82)
# (1.2529032236479323, 1.82)
# (1.2174048655321623, 1.82)
# (1.2884015817637022, 1.85)
# (1.3309996115026261, 1.86)
# (1.2174048655321623, 1.93)
# (1.5794881183130154, 2.08)
# (1.4800927155888595, 2.09)
# (2.0622657886874856, 2.71)
# (1.9912690724559459, 2.76)

# %%
fullPredictions.collect()
# Out:
# [Row(label=-3.74, features=DenseVector([3.75]), prediction=-2.65901584070991),
#  Row(label=-2.58, features=DenseVector([2.57]), prediction=-1.82125458917774),
#  Row(label=-2.26, features=DenseVector([2.25]), prediction=-1.594065097236813),
#  Row(label=-2.17, features=DenseVector([2.19]), prediction=-1.551467067497889),
#  Row(label=-2.12, features=DenseVector([1.9]), prediction=-1.3455765904264236),
#  Row(label=-2.09, features=DenseVector([1.97]), prediction=-1.3952742917885015),
#  Row(label=-2.07, features=DenseVector([2.04]), prediction=-1.4449719931505796),
#  Row(label=-1.94, features=DenseVector([1.94]), prediction=-1.3739752769190396),
#  Row(label=-1.94, features=DenseVector([1.98]), prediction=-1.4023739634116557),
#  Row(label=-1.91, features=DenseVector([1.83]), prediction=-1.295878889064346),
#  Row(label=-1.87, features=DenseVector([1.98]), prediction=-1.4023739634116557),
#  Row(label=-1.8, features=DenseVector([1.84]), prediction=-1.3029785606875),
#  Row(label=-1.79, features=DenseVector([1.73]), prediction=-1.224882172832806),
#  Row(label=-1.77, features=DenseVector([1.66]), prediction=-1.1751844714707282),
#  Row(label=-1.75, features=DenseVector([1.69]), prediction=-1.19648348634019),
#  Row(label=-1.66, features=DenseVector([1.64]), prediction=-1.1609851282244203),
#  Row(label=-1.64, features=DenseVector([1.84]), prediction=-1.3029785606875),
#  Row(label=-1.61, features=DenseVector([1.72]), prediction=-1.2177825012096521),
#  Row(label=-1.59, features=DenseVector([1.62]), prediction=-1.1467857849781125),
#  Row(label=-1.58, features=DenseVector([1.65]), prediction=-1.1680847998475743),
#  Row(label=-1.57, features=DenseVector([1.56]), prediction=-1.1041877552391886),
#  Row(label=-1.48, features=DenseVector([1.38]), prediction=-0.9763936660224167),
#  Row(label=-1.47, features=DenseVector([1.46]), prediction=-1.0331910390076486),
#  Row(label=-1.46, features=DenseVector([1.41]), prediction=-0.9976926808918786),
#  Row(label=-1.4, features=DenseVector([1.32]), prediction=-0.9337956362834929),
#  Row(label=-1.39, features=DenseVector([1.32]), prediction=-0.9337956362834929),
#  Row(label=-1.37, features=DenseVector([1.25]), prediction=-0.8840979349214151),
#  Row(label=-1.36, features=DenseVector([1.41]), prediction=-0.9976926808918786),
#  Row(label=-1.3, features=DenseVector([1.14]), prediction=-0.8060015470667212),
#  Row(label=-1.3, features=DenseVector([1.18]), prediction=-0.8344002335593372),
#  Row(label=-1.29, features=DenseVector([1.14]), prediction=-0.8060015470667212),
#  Row(label=-1.29, features=DenseVector([1.47]), prediction=-1.0402907106308026),
#  Row(label=-1.26, features=DenseVector([1.17]), prediction=-0.8273005619361832),
#  Row(label=-1.22, features=DenseVector([1.2]), prediction=-0.8485995768056451),
#  Row(label=-1.2, features=DenseVector([1.2]), prediction=-0.8485995768056451),
#  Row(label=-1.17, features=DenseVector([1.25]), prediction=-0.8840979349214151),
#  Row(label=-1.14, features=DenseVector([1.15]), prediction=-0.8131012186898753),
#  Row(label=-1.1, features=DenseVector([0.92]), prediction=-0.6498087713573338),
#  Row(label=-1.09, features=DenseVector([1.18]), prediction=-0.8344002335593372),
#  Row(label=-1.08, features=DenseVector([1.12]), prediction=-0.7918022038204134),
#  Row(label=-0.97, features=DenseVector([0.91]), prediction=-0.6427090997341799),
#  Row(label=-0.97, features=DenseVector([0.96]), prediction=-0.6782074578499497),
#  Row(label=-0.96, features=DenseVector([1.06]), prediction=-0.7492041740814895),
#  Row(label=-0.95, features=DenseVector([0.81]), prediction=-0.5717123835026401),
#  Row(label=-0.95, features=DenseVector([0.84]), prediction=-0.5930113983721019),
#  Row(label=-0.94, features=DenseVector([1.02]), prediction=-0.7208054875888736),
#  Row(label=-0.92, features=DenseVector([0.95]), prediction=-0.6711077862267957),
#  Row(label=-0.91, features=DenseVector([1.03]), prediction=-0.7279051592120276),
#  Row(label=-0.89, features=DenseVector([0.88]), prediction=-0.6214100848647179),
#  Row(label=-0.88, features=DenseVector([0.77]), prediction=-0.5433136970100242),
#  Row(label=-0.85, features=DenseVector([0.8]), prediction=-0.5646127118794861),
#  Row(label=-0.85, features=DenseVector([0.91]), prediction=-0.6427090997341799),
#  Row(label=-0.84, features=DenseVector([0.83]), prediction=-0.585911726748948),
#  Row(label=-0.82, features=DenseVector([0.7]), prediction=-0.49361599564794634),
#  Row(label=-0.81, features=DenseVector([0.89]), prediction=-0.6285097564878719),
#  Row(label=-0.8, features=DenseVector([0.73]), prediction=-0.5149150105174082),
#  Row(label=-0.8, features=DenseVector([0.8]), prediction=-0.5646127118794861),
#  Row(label=-0.8, features=DenseVector([0.8]), prediction=-0.5646127118794861),
#  Row(label=-0.78, features=DenseVector([0.66]), prediction=-0.46521730915533044),
#  Row(label=-0.78, features=DenseVector([0.81]), prediction=-0.5717123835026401),
#  Row(label=-0.76, features=DenseVector([0.66]), prediction=-0.46521730915533044),
#  Row(label=-0.76, features=DenseVector([0.84]), prediction=-0.5930113983721019),
#  Row(label=-0.75, features=DenseVector([0.72]), prediction=-0.5078153388942542),
#  Row(label=-0.74, features=DenseVector([0.93]), prediction=-0.6569084429804878),
#  Row(label=-0.73, features=DenseVector([0.62]), prediction=-0.43681862266271454),
#  Row(label=-0.71, features=DenseVector([0.55]), prediction=-0.3871209213006367),
#  Row(label=-0.68, features=DenseVector([0.76]), prediction=-0.5362140253868701),
#  Row(label=-0.68, features=DenseVector([0.88]), prediction=-0.6214100848647179),
#  Row(label=-0.66, features=DenseVector([0.65]), prediction=-0.4581176375321765),
#  Row(label=-0.65, features=DenseVector([0.54]), prediction=-0.38002124967748274),
#  Row(label=-0.65, features=DenseVector([0.57]), prediction=-0.4013202645469446),
#  Row(label=-0.65, features=DenseVector([0.88]), prediction=-0.6214100848647179),
#  Row(label=-0.62, features=DenseVector([0.58]), prediction=-0.4084199361700986),
#  Row(label=-0.62, features=DenseVector([0.68]), prediction=-0.47941665240163844),
#  Row(label=-0.6, features=DenseVector([0.56]), prediction=-0.3942205929237907),
#  Row(label=-0.6, features=DenseVector([0.61]), prediction=-0.42971895103956054),
#  Row(label=-0.59, features=DenseVector([0.39]), prediction=-0.27352617533017304),
#  Row(label=-0.57, features=DenseVector([0.54]), prediction=-0.38002124967748274),
#  Row(label=-0.54, features=DenseVector([0.52]), prediction=-0.36582190643117474),
#  Row(label=-0.53, features=DenseVector([0.31]), prediction=-0.21672880234494118),
#  Row(label=-0.51, features=DenseVector([0.69]), prediction=-0.48651632402479233),
#  Row(label=-0.49, features=DenseVector([0.44]), prediction=-0.30902453344594294),
#  Row(label=-0.49, features=DenseVector([0.44]), prediction=-0.30902453344594294),
#  Row(label=-0.42, features=DenseVector([0.45]), prediction=-0.3161242050690969),
#  Row(label=-0.39, features=DenseVector([0.27]), prediction=-0.18833011585232529),
#  Row(label=-0.35, features=DenseVector([0.33]), prediction=-0.23092814559124913),
#  Row(label=-0.35, features=DenseVector([0.47]), prediction=-0.33032354831540484),
#  Row(label=-0.34, features=DenseVector([0.25]), prediction=-0.17413077260601734),
#  Row(label=-0.33, features=DenseVector([0.3]), prediction=-0.20962913072178718),
#  Row(label=-0.3, features=DenseVector([0.35]), prediction=-0.24512748883755708),
#  Row(label=-0.29, features=DenseVector([0.34]), prediction=-0.23802781721440314),
#  Row(label=-0.28, features=DenseVector([0.29]), prediction=-0.20252945909863324),
#  Row(label=-0.27, features=DenseVector([0.16]), prediction=-0.11023372799763152),
#  Row(label=-0.26, features=DenseVector([0.23]), prediction=-0.1599314293597094),
#  Row(label=-0.25, features=DenseVector([0.28]), prediction=-0.1954297874754793),
#  Row(label=-0.24, features=DenseVector([0.27]), prediction=-0.18833011585232529),
#  Row(label=-0.23, features=DenseVector([0.24]), prediction=-0.16703110098286333),
#  Row(label=-0.22, features=DenseVector([0.29]), prediction=-0.20252945909863324),
#  Row(label=-0.21, features=DenseVector([0.11]), prediction=-0.07473536988186164),
#  Row(label=-0.19, features=DenseVector([0.29]), prediction=-0.20252945909863324),
#  Row(label=-0.19, features=DenseVector([0.44]), prediction=-0.30902453344594294),
#  Row(label=-0.18, features=DenseVector([0.14]), prediction=-0.09603438475132357),
#  Row(label=-0.17, features=DenseVector([0.19]), prediction=-0.13153274286709343),
#  Row(label=-0.16, features=DenseVector([0.32]), prediction=-0.2238284739680952),
#  Row(label=-0.13, features=DenseVector([0.09]), prediction=-0.06053602663555367),
#  Row(label=-0.1, features=DenseVector([0.05]), prediction=-0.032137340142937766),
#  Row(label=-0.09, features=DenseVector([0.1]), prediction=-0.06763569825870766),
#  Row(label=-0.09, features=DenseVector([0.16]), prediction=-0.11023372799763152),
#  Row(label=-0.09, features=DenseVector([0.17]), prediction=-0.11733339962078551),
#  Row(label=-0.08, features=DenseVector([0.14]), prediction=-0.09603438475132357),
#  Row(label=-0.07, features=DenseVector([-0.09]), prediction=0.06725806258121793),
#  Row(label=-0.07, features=DenseVector([-0.01]), prediction=0.010460689595986106),
#  Row(label=-0.07, features=DenseVector([0.06]), prediction=-0.03923701176609174),
#  Row(label=-0.07, features=DenseVector([0.22]), prediction=-0.15283175773655538),
#  Row(label=-0.05, features=DenseVector([-0.06]), prediction=0.045959047711756),
#  Row(label=-0.05, features=DenseVector([-0.02]), prediction=0.017560361219140085),
#  Row(label=-0.05, features=DenseVector([0.06]), prediction=-0.03923701176609174),
#  Row(label=-0.05, features=DenseVector([0.06]), prediction=-0.03923701176609174),
#  Row(label=-0.05, features=DenseVector([0.18]), prediction=-0.12443307124393947),
#  Row(label=-0.04, features=DenseVector([0.01]), prediction=-0.00373865365032185),
#  Row(label=-0.02, features=DenseVector([-0.04]), prediction=0.03175970446544804),
#  Row(label=0.0, features=DenseVector([-0.07]), prediction=0.05305871933490998),
#  Row(label=0.0, features=DenseVector([-0.06]), prediction=0.045959047711756),
#  Row(label=0.0, features=DenseVector([0.14]), prediction=-0.09603438475132357),
#  Row(label=0.02, features=DenseVector([-0.03]), prediction=0.024660032842294063),
#  Row(label=0.03, features=DenseVector([-0.04]), prediction=0.03175970446544804),
#  Row(label=0.04, features=DenseVector([0.01]), prediction=-0.00373865365032185),
#  Row(label=0.05, features=DenseVector([-0.07]), prediction=0.05305871933490998),
#  Row(label=0.05, features=DenseVector([-0.02]), prediction=0.017560361219140085),
#  Row(label=0.08, features=DenseVector([0.01]), prediction=-0.00373865365032185),
#  Row(label=0.08, features=DenseVector([0.04]), prediction=-0.025037668519783784),
#  Row(label=0.09, features=DenseVector([-0.11]), prediction=0.08145740582752589),
#  Row(label=0.1, features=DenseVector([-0.18]), prediction=0.13115510718960371),
#  Row(label=0.1, features=DenseVector([0.02]), prediction=-0.010838325273475828),
#  Row(label=0.11, features=DenseVector([-0.16]), prediction=0.11695576394329578),
#  Row(label=0.13, features=DenseVector([-0.11]), prediction=0.08145740582752589),
#  Row(label=0.14, features=DenseVector([-0.28]), prediction=0.20215182342114352),
#  Row(label=0.14, features=DenseVector([-0.11]), prediction=0.08145740582752589),
#  Row(label=0.15, features=DenseVector([-0.26]), prediction=0.18795248017483557),
#  Row(label=0.16, features=DenseVector([-0.2]), prediction=0.14535445043591172),
#  Row(label=0.16, features=DenseVector([-0.06]), prediction=0.045959047711756),
#  Row(label=0.17, features=DenseVector([-0.09]), prediction=0.06725806258121793),
#  Row(label=0.2, features=DenseVector([-0.26]), prediction=0.18795248017483557),
#  Row(label=0.21, features=DenseVector([-0.25]), prediction=0.18085280855168157),
#  Row(label=0.21, features=DenseVector([-0.23]), prediction=0.16665346530537362),
#  Row(label=0.21, features=DenseVector([-0.23]), prediction=0.16665346530537362),
#  Row(label=0.22, features=DenseVector([-0.31]), prediction=0.22345083829060547),
#  Row(label=0.23, features=DenseVector([-0.3]), prediction=0.21635116666745147),
#  Row(label=0.24, features=DenseVector([-0.27]), prediction=0.19505215179798957),
#  Row(label=0.25, features=DenseVector([-0.24]), prediction=0.17375313692852762),
#  Row(label=0.25, features=DenseVector([-0.09]), prediction=0.06725806258121793),
#  Row(label=0.26, features=DenseVector([-0.28]), prediction=0.20215182342114352),
#  Row(label=0.28, features=DenseVector([-0.35]), prediction=0.25184952478322137),
#  Row(label=0.29, features=DenseVector([-0.25]), prediction=0.18085280855168157),
#  Row(label=0.3, features=DenseVector([-0.29]), prediction=0.20925149504429746),
#  Row(label=0.31, features=DenseVector([-0.3]), prediction=0.21635116666745147),
#  Row(label=0.33, features=DenseVector([-0.25]), prediction=0.18085280855168157),
#  Row(label=0.34, features=DenseVector([-0.4]), prediction=0.28734788289899127),
#  Row(label=0.34, features=DenseVector([-0.4]), prediction=0.28734788289899127),
#  Row(label=0.34, features=DenseVector([-0.36]), prediction=0.2589491964063753),
#  Row(label=0.35, features=DenseVector([-0.34]), prediction=0.24474985316006742),
#  Row(label=0.36, features=DenseVector([-0.47]), prediction=0.33704558426106906),
#  Row(label=0.37, features=DenseVector([-0.36]), prediction=0.2589491964063753),
#  Row(label=0.39, features=DenseVector([-0.29]), prediction=0.20925149504429746),
#  Row(label=0.4, features=DenseVector([-0.45]), prediction=0.3228462410147611),
#  Row(label=0.4, features=DenseVector([-0.39]), prediction=0.28024821127583727),
#  Row(label=0.4, features=DenseVector([-0.36]), prediction=0.2589491964063753),
#  Row(label=0.41, features=DenseVector([-0.39]), prediction=0.28024821127583727),
#  Row(label=0.42, features=DenseVector([-0.43]), prediction=0.30864689776845317),
#  Row(label=0.42, features=DenseVector([-0.29]), prediction=0.20925149504429746),
#  Row(label=0.43, features=DenseVector([-0.47]), prediction=0.33704558426106906),
#  Row(label=0.44, features=DenseVector([-0.37]), prediction=0.2660488680295293),
#  Row(label=0.45, features=DenseVector([-0.42]), prediction=0.30154722614529916),
#  Row(label=0.46, features=DenseVector([-0.43]), prediction=0.30864689776845317),
#  Row(label=0.49, features=DenseVector([-0.44]), prediction=0.31574656939160717),
#  Row(label=0.5, features=DenseVector([-0.62]), prediction=0.44354065860837877),
#  Row(label=0.5, features=DenseVector([-0.48]), prediction=0.34414525588422307),
#  Row(label=0.51, features=DenseVector([-0.51]), prediction=0.365444270753685),
#  Row(label=0.53, features=DenseVector([-0.56]), prediction=0.4009426288694549),
#  Row(label=0.53, features=DenseVector([-0.49]), prediction=0.351244927507377),
#  Row(label=0.53, features=DenseVector([-0.47]), prediction=0.33704558426106906),
#  Row(label=0.54, features=DenseVector([-0.42]), prediction=0.30154722614529916),
#  Row(label=0.55, features=DenseVector([-0.68]), prediction=0.48613868834730267),
#  Row(label=0.55, features=DenseVector([-0.55]), prediction=0.3938429572463009),
#  Row(label=0.58, features=DenseVector([-0.57]), prediction=0.4080423004926088),
#  Row(label=0.59, features=DenseVector([-0.6]), prediction=0.42934131536207076),
#  Row(label=0.61, features=DenseVector([-0.48]), prediction=0.34414525588422307),
#  Row(label=0.65, features=DenseVector([-0.54]), prediction=0.38674328562314697),
#  Row(label=0.65, features=DenseVector([-0.45]), prediction=0.3228462410147611),
#  Row(label=0.66, features=DenseVector([-0.71]), prediction=0.5074377032167646),
#  Row(label=0.67, features=DenseVector([-0.73]), prediction=0.5216370464630725),
#  Row(label=0.69, features=DenseVector([-0.73]), prediction=0.5216370464630725),
#  Row(label=0.72, features=DenseVector([-0.91]), prediction=0.6494311356798442),
#  Row(label=0.74, features=DenseVector([-0.66]), prediction=0.47193934510099467),
#  Row(label=0.74, features=DenseVector([-0.58]), prediction=0.4151419721157628),
#  Row(label=0.75, features=DenseVector([-0.92]), prediction=0.6565308073029982),
#  Row(label=0.75, features=DenseVector([-0.6]), prediction=0.42934131536207076),
#  Row(label=0.76, features=DenseVector([-0.8]), prediction=0.5713347478251505),
#  Row(label=0.76, features=DenseVector([-0.77]), prediction=0.5500357329556885),
#  Row(label=0.81, features=DenseVector([-0.65]), prediction=0.4648396734778407),
#  Row(label=0.86, features=DenseVector([-0.89]), prediction=0.6352317924335362),
#  Row(label=0.89, features=DenseVector([-0.63]), prediction=0.4506403302315327),
#  Row(label=0.9, features=DenseVector([-0.83]), prediction=0.5926337626946123),
#  Row(label=0.93, features=DenseVector([-0.85]), prediction=0.6068331059409203),
#  Row(label=0.93, features=DenseVector([-0.79]), prediction=0.5642350762019964),
#  Row(label=0.94, features=DenseVector([-0.88]), prediction=0.6281321208103823),
#  Row(label=0.95, features=DenseVector([-0.79]), prediction=0.5642350762019964),
#  Row(label=0.97, features=DenseVector([-0.98]), prediction=0.699128837041922),
#  Row(label=0.97, features=DenseVector([-0.92]), prediction=0.6565308073029982),
#  Row(label=0.97, features=DenseVector([-0.85]), prediction=0.6068331059409203),
#  Row(label=1.01, features=DenseVector([-0.97]), prediction=0.692029165418768),
#  Row(label=1.05, features=DenseVector([-1.15]), prediction=0.8198232546355396),
#  Row(label=1.05, features=DenseVector([-0.8]), prediction=0.5713347478251505),
#  Row(label=1.07, features=DenseVector([-1.06]), prediction=0.7559262100271539),
#  Row(label=1.08, features=DenseVector([-1.08]), prediction=0.7701255532734619),
#  Row(label=1.1, features=DenseVector([-0.99]), prediction=0.706228508665076),
#  Row(label=1.11, features=DenseVector([-1.29]), prediction=0.9192186573596953),
#  Row(label=1.11, features=DenseVector([-1.16]), prediction=0.8269229262586936),
#  Row(label=1.14, features=DenseVector([-1.21]), prediction=0.8624212843744635),
#  Row(label=1.14, features=DenseVector([-1.09]), prediction=0.7772252248966158),
#  Row(label=1.15, features=DenseVector([-1.43]), prediction=1.018614060083851),
#  Row(label=1.2, features=DenseVector([-1.15]), prediction=0.8198232546355396),
#  Row(label=1.24, features=DenseVector([-1.18]), prediction=0.8411222695050016),
#  Row(label=1.27, features=DenseVector([-1.17]), prediction=0.8340225978818475),
#  Row(label=1.27, features=DenseVector([-1.11]), prediction=0.7914245681429238),
#  Row(label=1.28, features=DenseVector([-1.27]), prediction=0.9050193141133874),
#  Row(label=1.32, features=DenseVector([-1.53]), prediction=1.0896107763153908),
#  Row(label=1.37, features=DenseVector([-1.41]), prediction=1.0044147168375428),
#  Row(label=1.39, features=DenseVector([-1.48]), prediction=1.0541124181996209),
#  Row(label=1.39, features=DenseVector([-1.38]), prediction=0.9831157019680811),
#  Row(label=1.48, features=DenseVector([-1.49]), prediction=1.0612120898227748),
#  Row(label=1.5, features=DenseVector([-1.61]), prediction=1.1464081493006226),
#  Row(label=1.51, features=DenseVector([-1.61]), prediction=1.1464081493006226),
#  Row(label=1.54, features=DenseVector([-1.52]), prediction=1.0825111046922367),
#  Row(label=1.55, features=DenseVector([-1.23]), prediction=0.8766206276207714),
#  Row(label=1.59, features=DenseVector([-1.77]), prediction=1.2600028952710862),
#  Row(label=1.62, features=DenseVector([-1.8]), prediction=1.281301910140548),
#  Row(label=1.63, features=DenseVector([-1.62]), prediction=1.1535078209237766),
#  Row(label=1.63, features=DenseVector([-1.5]), prediction=1.0683117614459288),
#  Row(label=1.64, features=DenseVector([-1.5]), prediction=1.0683117614459288),
#  Row(label=1.72, features=DenseVector([-1.89]), prediction=1.3451989547489338),
#  Row(label=1.83, features=DenseVector([-1.7]), prediction=1.2103051939090084),
#  Row(label=1.9, features=DenseVector([-1.8]), prediction=1.281301910140548),
#  Row(label=2.09, features=DenseVector([-2.14]), prediction=1.5226907453277834),
#  Row(label=2.17, features=DenseVector([-2.02]), prediction=1.4374946858499356),
#  Row(label=2.25, features=DenseVector([-2.24]), prediction=1.5936874615593233),
#  Row(label=2.31, features=DenseVector([-2.3]), prediction=1.636285491298247),
#  Row(label=-3.54, features=DenseVector([3.44]), prediction=-2.4389260203921364),
#  Row(label=-2.89, features=DenseVector([2.89]), prediction=-2.0484440811186677),
#  Row(label=-2.6, features=DenseVector([2.58]), prediction=-1.8283542608008942),
#  Row(label=-2.45, features=DenseVector([2.44]), prediction=-1.7289588580767385),
#  Row(label=-2.22, features=DenseVector([2.15]), prediction=-1.5230683810052732),
#  Row(label=-2.0, features=DenseVector([2.02]), prediction=-1.4307726499042714),
#  Row(label=-1.97, features=DenseVector([1.85]), prediction=-1.310078232310654),
#  Row(label=-1.84, features=DenseVector([1.9]), prediction=-1.3455765904264236),
#  Row(label=-1.68, features=DenseVector([1.57]), prediction=-1.1112874268623425),
#  Row(label=-1.68, features=DenseVector([1.71]), prediction=-1.2106828295864982),
#  Row(label=-1.68, features=DenseVector([1.75]), prediction=-1.2390815160791142),
#  Row(label=-1.66, features=DenseVector([1.71]), prediction=-1.2106828295864982),
#  Row(label=-1.63, features=DenseVector([1.58]), prediction=-1.1183870984854964),
#  Row(label=-1.6, features=DenseVector([1.54]), prediction=-1.0899884119928807),
#  Row(label=-1.54, features=DenseVector([1.75]), prediction=-1.2390815160791142),
#  Row(label=-1.5, features=DenseVector([1.38]), prediction=-0.9763936660224167),
#  Row(label=-1.5, features=DenseVector([1.4]), prediction=-0.9905930092687247),
#  Row(label=-1.43, features=DenseVector([1.38]), prediction=-0.9763936660224167),
#  Row(label=-1.4, features=DenseVector([1.3]), prediction=-0.919596293037185),
#  Row(label=-1.36, features=DenseVector([1.37]), prediction=-0.9692939943992629),
#  Row(label=-1.35, features=DenseVector([1.24]), prediction=-0.8769982632982611),
#  Row(label=-1.34, features=DenseVector([1.33]), prediction=-0.940895307906647),
#  Row(label=-1.3, features=DenseVector([1.37]), prediction=-0.9692939943992629),
#  Row(label=-1.24, features=DenseVector([1.17]), prediction=-0.8273005619361832),
#  Row(label=-1.18, features=DenseVector([1.23]), prediction=-0.8698985916751071),
#  Row(label=-1.16, features=DenseVector([1.12]), prediction=-0.7918022038204134),
#  Row(label=-1.14, features=DenseVector([0.91]), prediction=-0.6427090997341799),
#  Row(label=-1.1, features=DenseVector([1.07]), prediction=-0.7563038457046435),
#  Row(label=-1.09, features=DenseVector([1.04]), prediction=-0.7350048308351815),
#  Row(label=-1.08, features=DenseVector([1.18]), prediction=-0.8344002335593372),
#  Row(label=-1.03, features=DenseVector([0.88]), prediction=-0.6214100848647179),
#  Row(label=-1.01, features=DenseVector([1.08]), prediction=-0.7634035173277975),
#  Row(label=-1.01, features=DenseVector([1.17]), prediction=-0.8273005619361832),
#  Row(label=-1.0, features=DenseVector([1.0]), prediction=-0.7066061443425656),
#  Row(label=-0.99, features=DenseVector([1.08]), prediction=-0.7634035173277975),
#  Row(label=-0.96, features=DenseVector([0.89]), prediction=-0.6285097564878719),
#  Row(label=-0.93, features=DenseVector([0.8]), prediction=-0.5646127118794861),
#  Row(label=-0.93, features=DenseVector([1.06]), prediction=-0.7492041740814895),
#  Row(label=-0.92, features=DenseVector([1.0]), prediction=-0.7066061443425656),
#  Row(label=-0.92, features=DenseVector([1.02]), prediction=-0.7208054875888736),
#  Row(label=-0.91, features=DenseVector([0.71]), prediction=-0.5007156672711003),
#  Row(label=-0.91, features=DenseVector([0.86]), prediction=-0.6072107416184099),
#  Row(label=-0.9, features=DenseVector([0.78]), prediction=-0.5504133686331781),
#  Row(label=-0.9, features=DenseVector([0.89]), prediction=-0.6285097564878719),
#  Row(label=-0.88, features=DenseVector([0.73]), prediction=-0.5149150105174082),
#  Row(label=-0.82, features=DenseVector([1.04]), prediction=-0.7350048308351815),
#  Row(label=-0.81, features=DenseVector([0.73]), prediction=-0.5149150105174082),
#  Row(label=-0.81, features=DenseVector([0.83]), prediction=-0.585911726748948),
#  Row(label=-0.81, features=DenseVector([0.86]), prediction=-0.6072107416184099),
#  Row(label=-0.81, features=DenseVector([0.95]), prediction=-0.6711077862267957),
#  Row(label=-0.8, features=DenseVector([0.8]), prediction=-0.5646127118794861),
#  Row(label=-0.79, features=DenseVector([0.91]), prediction=-0.6427090997341799),
#  Row(label=-0.78, features=DenseVector([0.95]), prediction=-0.6711077862267957),
#  Row(label=-0.76, features=DenseVector([0.87]), prediction=-0.6143104132415639),
#  Row(label=-0.75, features=DenseVector([0.84]), prediction=-0.5930113983721019),
#  Row(label=-0.74, features=DenseVector([0.68]), prediction=-0.47941665240163844),
#  Row(label=-0.73, features=DenseVector([0.54]), prediction=-0.38002124967748274),
#  Row(label=-0.73, features=DenseVector([0.63]), prediction=-0.4439182942858685),
#  Row(label=-0.73, features=DenseVector([0.74]), prediction=-0.5220146821405622),
#  Row(label=-0.7, features=DenseVector([0.55]), prediction=-0.3871209213006367),
#  Row(label=-0.7, features=DenseVector([0.77]), prediction=-0.5433136970100242),
#  Row(label=-0.65, features=DenseVector([0.73]), prediction=-0.5149150105174082),
#  Row(label=-0.64, features=DenseVector([0.62]), prediction=-0.43681862266271454),
#  Row(label=-0.63, features=DenseVector([0.55]), prediction=-0.3871209213006367),
#  Row(label=-0.62, features=DenseVector([0.6]), prediction=-0.42261927941640653),
#  Row(label=-0.61, features=DenseVector([0.63]), prediction=-0.4439182942858685),
#  Row(label=-0.6, features=DenseVector([0.53]), prediction=-0.37292157805432874),
#  Row(label=-0.57, features=DenseVector([0.42]), prediction=-0.29482519019963493),
#  Row(label=-0.56, features=DenseVector([0.64]), prediction=-0.4510179659090225),
#  Row(label=-0.55, features=DenseVector([0.48]), prediction=-0.33742321993855884),
#  Row(label=-0.54, features=DenseVector([0.4]), prediction=-0.28062584695332704),
#  Row(label=-0.48, features=DenseVector([0.69]), prediction=-0.48651632402479233),
#  Row(label=-0.47, features=DenseVector([0.47]), prediction=-0.33032354831540484),
#  Row(label=-0.44, features=DenseVector([0.45]), prediction=-0.3161242050690969),
#  Row(label=-0.44, features=DenseVector([0.5]), prediction=-0.3516225631848668),
#  Row(label=-0.42, features=DenseVector([0.46]), prediction=-0.3232238766922509),
#  Row(label=-0.42, features=DenseVector([0.49]), prediction=-0.3445228915617128),
#  Row(label=-0.41, features=DenseVector([0.27]), prediction=-0.18833011585232529),
#  Row(label=-0.4, features=DenseVector([0.22]), prediction=-0.15283175773655538),
#  Row(label=-0.4, features=DenseVector([0.56]), prediction=-0.3942205929237907),
#  Row(label=-0.39, features=DenseVector([0.22]), prediction=-0.15283175773655538),
#  Row(label=-0.39, features=DenseVector([0.45]), prediction=-0.3161242050690969),
#  Row(label=-0.38, features=DenseVector([0.17]), prediction=-0.11733339962078551),
#  Row(label=-0.37, features=DenseVector([0.44]), prediction=-0.30902453344594294),
#  Row(label=-0.37, features=DenseVector([0.61]), prediction=-0.42971895103956054),
#  Row(label=-0.36, features=DenseVector([0.48]), prediction=-0.33742321993855884),
#  Row(label=-0.35, features=DenseVector([0.25]), prediction=-0.17413077260601734),
#  Row(label=-0.34, features=DenseVector([0.32]), prediction=-0.2238284739680952),
#  Row(label=-0.34, features=DenseVector([0.32]), prediction=-0.2238284739680952),
#  Row(label=-0.34, features=DenseVector([0.39]), prediction=-0.27352617533017304),
#  Row(label=-0.32, features=DenseVector([0.25]), prediction=-0.17413077260601734),
#  Row(label=-0.3, features=DenseVector([0.28]), prediction=-0.1954297874754793),
#  Row(label=-0.3, features=DenseVector([0.4]), prediction=-0.28062584695332704),
#  Row(label=-0.29, features=DenseVector([0.41]), prediction=-0.287725518576481),
#  Row(label=-0.26, features=DenseVector([0.54]), prediction=-0.38002124967748274),
#  Row(label=-0.25, features=DenseVector([0.29]), prediction=-0.20252945909863324),
#  Row(label=-0.21, features=DenseVector([0.14]), prediction=-0.09603438475132357),
#  Row(label=-0.21, features=DenseVector([0.33]), prediction=-0.23092814559124913),
#  Row(label=-0.2, features=DenseVector([0.06]), prediction=-0.03923701176609174),
#  Row(label=-0.2, features=DenseVector([0.28]), prediction=-0.1954297874754793),
#  Row(label=-0.2, features=DenseVector([0.3]), prediction=-0.20962913072178718),
#  Row(label=-0.19, features=DenseVector([0.12]), prediction=-0.08183504150501561),
#  Row(label=-0.19, features=DenseVector([0.16]), prediction=-0.11023372799763152),
#  Row(label=-0.19, features=DenseVector([0.16]), prediction=-0.11023372799763152),
#  Row(label=-0.19, features=DenseVector([0.21]), prediction=-0.14573208611340138),
#  Row(label=-0.18, features=DenseVector([0.09]), prediction=-0.06053602663555367),
#  Row(label=-0.18, features=DenseVector([0.31]), prediction=-0.21672880234494118),
#  Row(label=-0.16, features=DenseVector([0.02]), prediction=-0.010838325273475828),
#  Row(label=-0.15, features=DenseVector([0.18]), prediction=-0.12443307124393947),
#  Row(label=-0.15, features=DenseVector([0.23]), prediction=-0.1599314293597094),
#  Row(label=-0.14, features=DenseVector([0.29]), prediction=-0.20252945909863324),
#  Row(label=-0.14, features=DenseVector([0.38]), prediction=-0.26642650370701904),
#  Row(label=-0.13, features=DenseVector([0.04]), prediction=-0.025037668519783784),
#  Row(label=-0.13, features=DenseVector([0.16]), prediction=-0.11023372799763152),
#  Row(label=-0.12, features=DenseVector([0.27]), prediction=-0.18833011585232529),
#  Row(label=-0.11, features=DenseVector([0.04]), prediction=-0.025037668519783784),
#  Row(label=-0.11, features=DenseVector([0.15]), prediction=-0.10313405637447753),
#  Row(label=-0.11, features=DenseVector([0.27]), prediction=-0.18833011585232529),
#  Row(label=-0.1, features=DenseVector([0.1]), prediction=-0.06763569825870766),
#  Row(label=-0.1, features=DenseVector([0.26]), prediction=-0.18123044422917128),
#  Row(label=-0.09, features=DenseVector([0.01]), prediction=-0.00373865365032185),
#  Row(label=-0.07, features=DenseVector([0.02]), prediction=-0.010838325273475828),
#  Row(label=-0.05, features=DenseVector([-0.11]), prediction=0.08145740582752589),
#  Row(label=-0.04, features=DenseVector([0.23]), prediction=-0.1599314293597094),
#  Row(label=-0.01, features=DenseVector([0.09]), prediction=-0.06053602663555367),
#  Row(label=-0.0, features=DenseVector([-0.06]), prediction=0.045959047711756),
#  Row(label=0.02, features=DenseVector([0.0]), prediction=0.0033610179728321282),
#  Row(label=0.03, features=DenseVector([-0.1]), prediction=0.07435773420437192),
#  Row(label=0.03, features=DenseVector([0.03]), prediction=-0.017937996896629806),
#  Row(label=0.06, features=DenseVector([-0.18]), prediction=0.13115510718960371),
#  Row(label=0.06, features=DenseVector([-0.14]), prediction=0.10275642069698783),
#  Row(label=0.08, features=DenseVector([-0.19]), prediction=0.13825477881275772),
#  Row(label=0.1, features=DenseVector([-0.22]), prediction=0.15955379368221967),
#  Row(label=0.1, features=DenseVector([-0.12]), prediction=0.08855707745067987),
#  Row(label=0.11, features=DenseVector([-0.14]), prediction=0.10275642069698783),
#  Row(label=0.11, features=DenseVector([-0.04]), prediction=0.03175970446544804),
#  Row(label=0.12, features=DenseVector([0.01]), prediction=-0.00373865365032185),
#  Row(label=0.14, features=DenseVector([-0.31]), prediction=0.22345083829060547),
#  Row(label=0.14, features=DenseVector([-0.08]), prediction=0.060158390958063954),
#  Row(label=0.17, features=DenseVector([-0.02]), prediction=0.017560361219140085),
#  Row(label=0.18, features=DenseVector([-0.39]), prediction=0.28024821127583727),
#  Row(label=0.18, features=DenseVector([-0.07]), prediction=0.05305871933490998),
#  Row(label=0.19, features=DenseVector([-0.22]), prediction=0.15955379368221967),
#  Row(label=0.19, features=DenseVector([-0.09]), prediction=0.06725806258121793),
#  Row(label=0.21, features=DenseVector([-0.36]), prediction=0.2589491964063753),
#  Row(label=0.21, features=DenseVector([-0.18]), prediction=0.13115510718960371),
#  Row(label=0.22, features=DenseVector([-0.38]), prediction=0.27314853965268326),
#  Row(label=0.22, features=DenseVector([-0.32]), prediction=0.23055050991375942),
#  Row(label=0.24, features=DenseVector([-0.28]), prediction=0.20215182342114352),
#  Row(label=0.24, features=DenseVector([-0.22]), prediction=0.15955379368221967),
#  Row(label=0.25, features=DenseVector([-0.24]), prediction=0.17375313692852762),
#  Row(label=0.29, features=DenseVector([-0.27]), prediction=0.19505215179798957),
#  Row(label=0.3, features=DenseVector([-0.26]), prediction=0.18795248017483557),
#  Row(label=0.31, features=DenseVector([-0.31]), prediction=0.22345083829060547),
#  Row(label=0.32, features=DenseVector([-0.38]), prediction=0.27314853965268326),
#  Row(label=0.32, features=DenseVector([-0.2]), prediction=0.14535445043591172),
#  Row(label=0.33, features=DenseVector([-0.17]), prediction=0.12405543556644977),
#  Row(label=0.34, features=DenseVector([-0.52]), prediction=0.37254394237683897),
#  Row(label=0.35, features=DenseVector([-0.5]), prediction=0.358344599130531),
#  Row(label=0.35, features=DenseVector([-0.13]), prediction=0.09565674907383384),
#  Row(label=0.37, features=DenseVector([-0.47]), prediction=0.33704558426106906),
#  Row(label=0.38, features=DenseVector([-0.52]), prediction=0.37254394237683897),
#  Row(label=0.38, features=DenseVector([-0.46]), prediction=0.3299459126379151),
#  Row(label=0.38, features=DenseVector([-0.39]), prediction=0.28024821127583727),
#  Row(label=0.4, features=DenseVector([-0.46]), prediction=0.3299459126379151),
#  Row(label=0.44, features=DenseVector([-0.38]), prediction=0.27314853965268326),
#  Row(label=0.45, features=DenseVector([-0.65]), prediction=0.4648396734778407),
#  Row(label=0.45, features=DenseVector([-0.63]), prediction=0.4506403302315327),
#  Row(label=0.45, features=DenseVector([-0.47]), prediction=0.33704558426106906),
#  Row(label=0.51, features=DenseVector([-0.31]), prediction=0.22345083829060547),
#  Row(label=0.53, features=DenseVector([-0.28]), prediction=0.20215182342114352),
#  Row(label=0.55, features=DenseVector([-0.33]), prediction=0.23765018153691342),
#  Row(label=0.6, features=DenseVector([-0.69]), prediction=0.49323835997045656),
#  Row(label=0.61, features=DenseVector([-0.75]), prediction=0.5358363897093805),
#  Row(label=0.61, features=DenseVector([-0.56]), prediction=0.4009426288694549),
#  Row(label=0.63, features=DenseVector([-0.7]), prediction=0.5003380315936106),
#  Row(label=0.63, features=DenseVector([-0.65]), prediction=0.4648396734778407),
#  Row(label=0.64, features=DenseVector([-0.48]), prediction=0.34414525588422307),
#  Row(label=0.65, features=DenseVector([-0.64]), prediction=0.4577400018546867),
#  Row(label=0.67, features=DenseVector([-0.8]), prediction=0.5713347478251505),
#  Row(label=0.68, features=DenseVector([-0.84]), prediction=0.5997334343177663),
#  Row(label=0.68, features=DenseVector([-0.74]), prediction=0.5287367180862266),
#  Row(label=0.68, features=DenseVector([-0.63]), prediction=0.4506403302315327),
#  Row(label=0.69, features=DenseVector([-0.87]), prediction=0.6210324491872282),
#  Row(label=0.69, features=DenseVector([-0.73]), prediction=0.5216370464630725),
#  Row(label=0.7, features=DenseVector([-0.82]), prediction=0.5855340910714584),
#  Row(label=0.73, features=DenseVector([-0.7]), prediction=0.5003380315936106),
#  Row(label=0.74, features=DenseVector([-0.78]), prediction=0.5571354045788425),
#  Row(label=0.74, features=DenseVector([-0.6]), prediction=0.42934131536207076),
#  Row(label=0.75, features=DenseVector([-0.85]), prediction=0.6068331059409203),
#  Row(label=0.77, features=DenseVector([-0.74]), prediction=0.5287367180862266),
#  Row(label=0.78, features=DenseVector([-0.8]), prediction=0.5713347478251505),
#  Row(label=0.78, features=DenseVector([-0.69]), prediction=0.49323835997045656),
#  Row(label=0.81, features=DenseVector([-0.81]), prediction=0.5784344194483044),
#  Row(label=0.86, features=DenseVector([-0.96]), prediction=0.6849294937956141),
#  Row(label=0.87, features=DenseVector([-1.02]), prediction=0.727527523534538),
#  Row(label=0.88, features=DenseVector([-0.8]), prediction=0.5713347478251505),
#  Row(label=0.9, features=DenseVector([-0.92]), prediction=0.6565308073029982),
#  Row(label=0.9, features=DenseVector([-0.9]), prediction=0.6423314640566902),
#  Row(label=0.9, features=DenseVector([-0.72]), prediction=0.5145373748399186),
#  Row(label=0.93, features=DenseVector([-0.96]), prediction=0.6849294937956141),
#  Row(label=0.95, features=DenseVector([-1.05]), prediction=0.7488265384039999),
#  Row(label=0.95, features=DenseVector([-1.04]), prediction=0.7417268667808459),
#  Row(label=0.95, features=DenseVector([-0.89]), prediction=0.6352317924335362),
#  Row(label=0.95, features=DenseVector([-0.86]), prediction=0.6139327775640743),
#  Row(label=0.96, features=DenseVector([-1.05]), prediction=0.7488265384039999),
#  Row(label=0.98, features=DenseVector([-1.15]), prediction=0.8198232546355396),
#  Row(label=0.99, features=DenseVector([-1.0]), prediction=0.71332818028823),
#  Row(label=0.99, features=DenseVector([-0.88]), prediction=0.6281321208103823),
#  Row(label=1.0, features=DenseVector([-1.08]), prediction=0.7701255532734619),
#  Row(label=1.0, features=DenseVector([-1.04]), prediction=0.7417268667808459),
#  Row(label=1.01, features=DenseVector([-0.94]), prediction=0.6707301505493061),
#  Row(label=1.01, features=DenseVector([-0.9]), prediction=0.6423314640566902),
#  Row(label=1.02, features=DenseVector([-1.05]), prediction=0.7488265384039999),
#  Row(label=1.04, features=DenseVector([-1.05]), prediction=0.7488265384039999),
#  Row(label=1.05, features=DenseVector([-1.01]), prediction=0.7204278519113839),
#  Row(label=1.05, features=DenseVector([-0.88]), prediction=0.6281321208103823),
#  Row(label=1.06, features=DenseVector([-1.11]), prediction=0.7914245681429238),
#  Row(label=1.08, features=DenseVector([-1.11]), prediction=0.7914245681429238),
#  Row(label=1.1, features=DenseVector([-0.95]), prediction=0.67782982217246),
#  Row(label=1.13, features=DenseVector([-1.25]), prediction=0.8908199708670794),
#  Row(label=1.17, features=DenseVector([-1.21]), prediction=0.8624212843744635),
#  Row(label=1.19, features=DenseVector([-1.12]), prediction=0.7985242397660778),
#  Row(label=1.2, features=DenseVector([-1.2]), prediction=0.8553216127513095),
#  Row(label=1.25, features=DenseVector([-1.33]), prediction=0.9476173438523113),
#  Row(label=1.28, features=DenseVector([-1.2]), prediction=0.8553216127513095),
#  Row(label=1.38, features=DenseVector([-1.33]), prediction=0.9476173438523113),
#  Row(label=1.41, features=DenseVector([-1.47]), prediction=1.0470127465764667),
#  Row(label=1.5, features=DenseVector([-1.56]), prediction=1.1109097911848527),
#  Row(label=1.53, features=DenseVector([-1.75]), prediction=1.2458035520247783),
#  Row(label=1.53, features=DenseVector([-1.58]), prediction=1.1251091344311606),
#  Row(label=1.53, features=DenseVector([-1.45]), prediction=1.0328134033301588),
#  Row(label=1.54, features=DenseVector([-1.72]), prediction=1.2245045371553163),
#  Row(label=1.54, features=DenseVector([-1.6]), prediction=1.1393084776774687),
#  Row(label=1.56, features=DenseVector([-1.62]), prediction=1.1535078209237766),
#  Row(label=1.61, features=DenseVector([-1.64]), prediction=1.1677071641700845),
#  Row(label=1.65, features=DenseVector([-1.57]), prediction=1.1180094628080066),
#  Row(label=1.74, features=DenseVector([-1.52]), prediction=1.0825111046922367),
#  Row(label=1.78, features=DenseVector([-1.94]), prediction=1.3806973128647038),
#  Row(label=1.78, features=DenseVector([-1.77]), prediction=1.2600028952710862),
#  Row(label=1.8, features=DenseVector([-1.69]), prediction=1.2032055222858542),
#  Row(label=1.82, features=DenseVector([-1.84]), prediction=1.309700596633164),
#  Row(label=1.82, features=DenseVector([-1.76]), prediction=1.2529032236479323),
#  Row(label=1.82, features=DenseVector([-1.71]), prediction=1.2174048655321623),
#  Row(label=1.85, features=DenseVector([-1.81]), prediction=1.2884015817637022),
#  Row(label=1.86, features=DenseVector([-1.87]), prediction=1.3309996115026261),
#  Row(label=1.93, features=DenseVector([-1.71]), prediction=1.2174048655321623),
#  Row(label=2.08, features=DenseVector([-2.22]), prediction=1.5794881183130154),
#  Row(label=2.09, features=DenseVector([-2.08]), prediction=1.4800927155888595),
#  Row(label=2.71, features=DenseVector([-2.9]), prediction=2.0622657886874856),
#  Row(label=2.76, features=DenseVector([-2.8]), prediction=1.9912690724559459)]
